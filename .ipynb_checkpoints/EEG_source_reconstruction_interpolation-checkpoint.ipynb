# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
torch.manual_seed(2)

# %%
def get_model_parameters(N, T, device):
    """
    Initializes the parameters of the model
    Input:
        N: int, Number of sources for the model
        T: int, Length of time signals from which we wish to reconstruct the sources
        device: instance of class torch.optim.Adam
    Output:
        Beta: torch.tensor of 1 element, parameter that embodies the delay between a source and a distant point due to speed of signal propagation
        Gamma: torch.tensor of size=(N,), scales the decay in 1/r² of source signals as follows: 
            amplitude ~ 1/(1+Gamma[i]*r²) where r is the distance to the source i. This way, each source can have its own space decay factor
        Sources_pos: torch.tensor of size=(N,2). Source_pos[i,:] is the coordinates of the source n°i
        Sources: torch.tensor of size=(N,T). Sources[i,:] is the signal of the source n°i
    """
    # initialize Beta to 0
    Beta = torch.tensor(0., dtype=torch.float32, requires_grad = True, device=device)
    # initialize each Gamma to 20 (arbitrary)
    Gamma = 20*torch.ones(size=(N,), dtype=torch.float32, device=device)
    Gamma.requires_grad_()
    # initialize the sources locations as random values in [0,1]x[0,1]
    Sources_pos = torch.rand(size=(N,2), dtype=torch.float32, requires_grad = True, device=device)
    # initialize each source to a zero-signal of length T
    Sources = torch.zeros(size=(N,T), dtype=torch.float32, requires_grad = True, device=device)
    return Beta, Gamma, Sources_pos, Sources


def predict(X, parameters):
    """
    Function that takes as input a location in space and the parameters of the model and that returns the estimated signal at this location
    Input:
        X: torch.tensor of size (2,) 
        parameters: [Beta, Gamma, Sources_pos, Sources]
    Output:
        Y: torch.tensor of size=(T,) where T is the length of the source signals. Y is the estimated signal at the X location
    """
    pos = X.reshape(1,2)
    Beta, Gamma, Sources_pos, Sources = parameters
    N, T = Sources.shape

    # initialize output to a zero-signal of length T
    Y = torch.zeros(size=(T,))
    # compute the pairwise distance (L2 norm) between X and each source
    pairwise_dist = torch.cdist(Sources_pos, pos, p=2.0)
    if Beta==0:
        # in case if we do not want to model the time delay due to the distance to the source.
        Sources_delayed = Sources # no delay
    else:
        Sources_delayed = torch.zeros_like(Sources)
        # we want the output to be a weighted sum of the sources considering the time delay due to the distance to each source
        for i in range(N):
            # we first compute the delayed source signal n°i at the location X without rescaling the signal
            # we model it as follows: delayed_source_i(loc=X, time=t) = source_i(time=t-Beta*dist(source_loc_i, X))
            dist = pairwise_dist[i]
            Sources_delayed[i,int(Beta*dist):] = Sources[i,:T-int(Beta*dist)]
        Sources_delayed.requires_grad_()
    # Compute the weighted sum of the delayed sources with the factors 1/(1+gamma[i]*dist²(source_loc_i, X))
    Y = torch.sum(1/(1+Gamma.reshape(-1,1)*pairwise_dist.reshape(-1,1)**2) * Sources_delayed, dim=0)
    Y.requires_grad_()
    
    return Y

def Beta_gradient(Y_true, Y, X, parameters):
    """
    Function that computes the gradient of the loss (defined below) with respect to the parameter Beta. 
    loss = sum_{t=1:T,i=1:N}(||Y_i(t)-Y_true_i(t)||²)
    Because the loss was not differentiable with respect to this parameter (which appears in the indices of the tensors with requires_grad=True), 
    it was necessary to give an explicit value of the gradient.
    Input:
        Y_true: torch.tensor of size=(T,). Real signal at the location X (supposed to be an EEG channel)
        Y: torch.tensor of size=(T,). Estimated signal at location X with the model and the parameters
        X: torch.tensor of size (2,). Location of channel
        parameters: [Beta, Gamma, Sources_pos, Sources]
    Output:
        Y: torch.tensor of size=(T,) where T is the length of the source signals. Y is the estimated signal at the X location
    """
    Beta, Gamma, Sources_pos, Sources = parameters
    N, T = Sources.shape
    J = Y_true.shape[0]
    pairwise_dist = torch.cdist(Sources_pos, X, p=2.0)
    mini, maxi = torch.tensor(0), torch.tensor(T)
    Sources_delayed = torch.zeros(size=(N,J,T))
    for i in range(N):
        for j in range(J):
            dist = pairwise_dist[i,j]
            index = torch.tensor(int(Beta*dist))
            Sources_delayed[i,j,torch.clamp(index,mini,maxi):] = Sources[i,:torch.clamp(T-index, mini,maxi)]
            
    Shifted = torch.roll(Sources_delayed, -1, 2)
    grad = 0
    for i in range(N):
        for j in range(J):
            grad += torch.sum(2*(Y_true[j,:]-Y[j,:]) * pairwise_dist[i,j]/(1+Gamma[i]*pairwise_dist[i,j]**2) * (Shifted[i,j,:] - Sources_delayed[i,j,:]))
    return 0.1*grad

# %%
def train_model(num_steps, parameters, X, Y_true, lr=1e-3, verbose=True, learn_Beta=False):
    """
    Trains the model by learning the parameters to best reproduce the signals Y_true at the channels locations X
    Input:
        num_steps: int, steps of learning
        parameters: [Beta, Gamma, Sources_pos, Sources]
        Y_true: torch.tensor of size=(T,). Real signal at the location X (supposed to be an EEG channel)
        X: torch.tensor of size (2,). Location of channel
        lr: float, learning rate
        verbose: Bool. If True, plot the loss against time at the end of the learning
    Output: Stored values of the parameters during the learning. Useful for plots. 
        torch.tensor(Betas)
        torch.tensor(Gammas)
        torch.tensor(positions)
    """
    Beta, Gamma, Sources_pos, Sources = parameters
    optimizer = torch.optim.Adam(parameters, lr)
    losses = []
    Betas = []
    Gammas = []
    positions = []
    for step in range(num_steps):
        # predict signals at locations X with current parameters
        Y = torch.zeros_like(Y_true)
        # compute quadratic loss (MSE)
        loss = 0
        for k in range(len(X)):
            Y[k] = predict(X[k], parameters)
            loss += torch.sum((Y[k] -Y_true[k])**2)
        print("loss:", loss)
        # compute the gradient of the loss with respect to parameter Beta (considered at non-differentiable by pytorch because of indexing)
        if learn_Beta:
            Beta_update = torch.clamp(Beta - lr*Beta_gradient(Y_true, Y, X, parameters), 0, None)
            Beta.data = torch.tensor(Beta_update)
        loss.backward()
        losses.append(loss.item())
        Betas.append(Beta.item())
        Gammas.append(Gamma.clone().detach().tolist())
        positions.append(Sources_pos.clone().detach().tolist())
        if verbose and step % 100 == 0:
            print(f"step={step} - loss={loss.item():0.4f}")
        optimizer.step()
        optimizer.zero_grad()

    if verbose:
        plt.plot(losses)
        plt.xlabel("Step")
        plt.ylabel("Loss")
        plt.show()

    return torch.tensor(Betas), torch.tensor(Gammas), torch.tensor(positions)

# %%
# build a fake dataset
# number of recording channels
n_channels = 50
channels_pos = torch.rand(n_channels,2)

# number of real sources
n_sources = 8
sources_pos_true = torch.rand(n_sources,2)

# time window
T = 100

# signals at the sources
sources_true = torch.zeros((n_sources,T))
sources_true[0,:] = 1* torch.cos(torch.linspace(0,20,T))
sources_true[1,:] = torch.sin(2*torch.linspace(0,20,T))
sources_true[2,:] = 0.5*torch.cos(3*torch.linspace(0,20,T))
sources_true[3,:] = torch.sin(torch.exp(torch.linspace(0,20,T)))
sources_true[4,:] = 0.1*torch.cos(8*torch.linspace(0,20,T))
sources_true[5,:] = torch.sin(2*torch.linspace(0,20,T))
sources_true[6,:] = 0.1*torch.cos(2*torch.linspace(0,20,T))
sources_true[7,:] = 0.5*torch.cos(torch.exp(torch.linspace(0,20,T)))

# choose the parameters for the propagation and space decay of sources
Beta = torch.tensor(0.)
Gamma = 20*torch.ones(size=(n_sources,))
exact_parameters = Beta, Gamma, sources_pos_true, sources_true

# compute the signals at the channel locations using these parameters
Channels = torch.zeros((n_channels, T))
for j in range(n_channels):
    with torch.no_grad():
        Channels[j,:] = predict(channels_pos[j], exact_parameters)

# %%
# Set this to 'cuda' if you have a GPU available.
device = torch.device("cpu")
steps = 1000
lr = 1e-2

# Create dataset and move to device
# X : locations of the channels
X = channels_pos
# Y_true: true signals at these locations
Y_true = torch.tensor(Channels, dtype=torch.float32)
X = X.to(device)
Y_true = Y_true.to(device)

# Create model
# Number of sources we wish to model
N = 10
parameters = get_model_parameters(N, T, device)


def initialize_sources(parameters, X, Y_true, device, init_steps, lr):
    """
    Creates an intermediate model to make the learning faster.
    This function makes a first update of the parameters of the model, using a source reconstruction based on signal power.
    Input:
        parameters: [Beta, Gamma, Sources_pos, Sources]
        X: torch.tensor of size (2,). Location of channel
        Y_true: torch.tensor of size=(T,). Real signal at the location X (supposed to be an EEG channel)
        init_steps: number of learning steps during the source power reconstruction
    Output:
        power_parameters: parameters of the model that predicts the power of signal at any location x considering the powers at the channels locations
        Betas_power: values of Beta during this first approximation phase
        Gammas_power: values of Gamma
        positions_power: successive positions of the sources during this first approximation phase
    """
    Beta, Gamma, Sources_pos, Sources = parameters
    N, T = Sources.shape
    # compute the received power at each channel location
    Y_power_true = torch.sqrt(torch.sum(Y_true**2, dim=1))
    # build a model of power sources reconstruction
    power_parameters = get_model_parameters(N, 1, device)
    # train the model to estimate the source locations as well as Gamma and Beta
    Betas_power, Gammas_power, positions_power = train_model(init_steps, power_parameters, X, Y_power_true, lr, learn_Beta=False)
    # get the updated model parameters
    Beta_power, Gamma_power, Sources_pos_power, Sources_power = power_parameters
    # use these values to do the first update of the final model parameters
    Gamma.data = Gamma_power.clone().detach()
    Sources_pos.data = Sources_pos_power.clone().detach()
    return power_parameters, Betas_power, Gammas_power, positions_power

# Estimate the sources positions using the power of the signal at the channels.
init_steps = 500
power_parameters, Betas_power, Gammas_power, positions_power = initialize_sources(parameters, X, Y_true, device, init_steps, lr)

# Train the final model
torch.autograd.set_detect_anomaly(True)
Betas, Gammas, positions = train_model(steps, parameters, X, Y_true, lr, learn_Beta=False)
# Out:
# <ipython-input-5-fff8aca0a35b>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Y_true = torch.tensor(Channels, dtype=torch.float32)
# loss: tensor(1019.4088, grad_fn=<AddBackward0>)
# step=0 - loss=1019.4088
# loss: tensor(1009.3926, grad_fn=<AddBackward0>)
# loss: tensor(999.0696, grad_fn=<AddBackward0>)
# loss: tensor(988.3856, grad_fn=<AddBackward0>)
# loss: tensor(977.3337, grad_fn=<AddBackward0>)
# loss: tensor(965.9171, grad_fn=<AddBackward0>)
# loss: tensor(954.1423, grad_fn=<AddBackward0>)
# loss: tensor(942.0175, grad_fn=<AddBackward0>)
# loss: tensor(929.5480, grad_fn=<AddBackward0>)
# loss: tensor(916.7434, grad_fn=<AddBackward0>)
# loss: tensor(903.6216, grad_fn=<AddBackward0>)
# loss: tensor(890.2087, grad_fn=<AddBackward0>)
# loss: tensor(876.5329, grad_fn=<AddBackward0>)
# loss: tensor(862.6229, grad_fn=<AddBackward0>)
# loss: tensor(848.5052, grad_fn=<AddBackward0>)
# loss: tensor(834.2083, grad_fn=<AddBackward0>)
# loss: tensor(819.7695, grad_fn=<AddBackward0>)
# loss: tensor(805.2336, grad_fn=<AddBackward0>)
# loss: tensor(790.6480, grad_fn=<AddBackward0>)
# loss: tensor(776.0558, grad_fn=<AddBackward0>)
# loss: tensor(761.4925, grad_fn=<AddBackward0>)
# loss: tensor(746.9893, grad_fn=<AddBackward0>)
# loss: tensor(732.5767, grad_fn=<AddBackward0>)
# loss: tensor(718.2793, grad_fn=<AddBackward0>)
# loss: tensor(704.1095, grad_fn=<AddBackward0>)
# loss: tensor(690.0645, grad_fn=<AddBackward0>)
# loss: tensor(676.1385, grad_fn=<AddBackward0>)
# loss: tensor(662.3342, grad_fn=<AddBackward0>)
# loss: tensor(648.6672, grad_fn=<AddBackward0>)
# loss: tensor(635.1657, grad_fn=<AddBackward0>)
# loss: tensor(621.8661, grad_fn=<AddBackward0>)
# loss: tensor(608.8083, grad_fn=<AddBackward0>)
# loss: tensor(596.0310, grad_fn=<AddBackward0>)
# loss: tensor(583.5676, grad_fn=<AddBackward0>)
# loss: tensor(571.4454, grad_fn=<AddBackward0>)
# loss: tensor(559.6840, grad_fn=<AddBackward0>)
# loss: tensor(548.2982, grad_fn=<AddBackward0>)
# loss: tensor(537.2985, grad_fn=<AddBackward0>)
# loss: tensor(526.6921, grad_fn=<AddBackward0>)
# loss: tensor(516.4835, grad_fn=<AddBackward0>)
# loss: tensor(506.6726, grad_fn=<AddBackward0>)
# loss: tensor(497.2539, grad_fn=<AddBackward0>)
# loss: tensor(488.2154, grad_fn=<AddBackward0>)
# loss: tensor(479.5378, grad_fn=<AddBackward0>)
# loss: tensor(471.1958, grad_fn=<AddBackward0>)
# loss: tensor(463.1584, grad_fn=<AddBackward0>)
# loss: tensor(455.3920, grad_fn=<AddBackward0>)
# loss: tensor(447.8624, grad_fn=<AddBackward0>)
# loss: tensor(440.5379, grad_fn=<AddBackward0>)
# loss: tensor(433.3893, grad_fn=<AddBackward0>)
# loss: tensor(426.3922, grad_fn=<AddBackward0>)
# loss: tensor(419.5264, grad_fn=<AddBackward0>)
# loss: tensor(412.7760, grad_fn=<AddBackward0>)
# loss: tensor(406.1301, grad_fn=<AddBackward0>)
# loss: tensor(399.5811, grad_fn=<AddBackward0>)
# loss: tensor(393.1261, grad_fn=<AddBackward0>)
# loss: tensor(386.7661, grad_fn=<AddBackward0>)
# loss: tensor(380.5070, grad_fn=<AddBackward0>)
# loss: tensor(374.3585, grad_fn=<AddBackward0>)
# loss: tensor(368.3312, grad_fn=<AddBackward0>)
# loss: tensor(362.4341, grad_fn=<AddBackward0>)
# loss: tensor(356.6662, grad_fn=<AddBackward0>)
# loss: tensor(351.0113, grad_fn=<AddBackward0>)
# loss: tensor(345.4408, grad_fn=<AddBackward0>)
# loss: tensor(339.9254, grad_fn=<AddBackward0>)
# loss: tensor(334.4478, grad_fn=<AddBackward0>)
# loss: tensor(329.0058, grad_fn=<AddBackward0>)
# loss: tensor(323.6078, grad_fn=<AddBackward0>)
# loss: tensor(318.2683, grad_fn=<AddBackward0>)
# loss: tensor(313.0021, grad_fn=<AddBackward0>)
# loss: tensor(307.8212, grad_fn=<AddBackward0>)
# loss: tensor(302.7319, grad_fn=<AddBackward0>)
# loss: tensor(297.7360, grad_fn=<AddBackward0>)
# loss: tensor(292.8325, grad_fn=<AddBackward0>)
# loss: tensor(288.0205, grad_fn=<AddBackward0>)
# loss: tensor(283.3002, grad_fn=<AddBackward0>)
# loss: tensor(278.6725, grad_fn=<AddBackward0>)
# loss: tensor(274.1378, grad_fn=<AddBackward0>)
# loss: tensor(269.6960, grad_fn=<AddBackward0>)
# loss: tensor(265.3470, grad_fn=<AddBackward0>)
# loss: tensor(261.0912, grad_fn=<AddBackward0>)
# loss: tensor(256.9284, grad_fn=<AddBackward0>)
# loss: tensor(252.8566, grad_fn=<AddBackward0>)
# loss: tensor(248.8717, grad_fn=<AddBackward0>)
# loss: tensor(244.9684, grad_fn=<AddBackward0>)
# loss: tensor(241.1407, grad_fn=<AddBackward0>)
# loss: tensor(237.3836, grad_fn=<AddBackward0>)
# loss: tensor(233.6920, grad_fn=<AddBackward0>)
# loss: tensor(230.0610, grad_fn=<AddBackward0>)
# loss: tensor(226.4860, grad_fn=<AddBackward0>)
# loss: tensor(222.9641, grad_fn=<AddBackward0>)
# loss: tensor(219.4942, grad_fn=<AddBackward0>)
# loss: tensor(216.0760, grad_fn=<AddBackward0>)
# loss: tensor(212.7098, grad_fn=<AddBackward0>)
# loss: tensor(209.3956, grad_fn=<AddBackward0>)
# loss: tensor(206.1336, grad_fn=<AddBackward0>)
# loss: tensor(202.9243, grad_fn=<AddBackward0>)
# loss: tensor(199.7677, grad_fn=<AddBackward0>)
# loss: tensor(196.6631, grad_fn=<AddBackward0>)
# loss: tensor(193.6097, grad_fn=<AddBackward0>)
# loss: tensor(190.6073, grad_fn=<AddBackward0>)
# step=100 - loss=190.6073
# loss: tensor(187.6556, grad_fn=<AddBackward0>)
# loss: tensor(184.7549, grad_fn=<AddBackward0>)
# loss: tensor(181.9052, grad_fn=<AddBackward0>)
# loss: tensor(179.1064, grad_fn=<AddBackward0>)
# loss: tensor(176.3583, grad_fn=<AddBackward0>)
# loss: tensor(173.6607, grad_fn=<AddBackward0>)
# loss: tensor(171.0126, grad_fn=<AddBackward0>)
# loss: tensor(168.4130, grad_fn=<AddBackward0>)
# loss: tensor(165.8601, grad_fn=<AddBackward0>)
# loss: tensor(163.3527, grad_fn=<AddBackward0>)
# loss: tensor(160.8903, grad_fn=<AddBackward0>)
# loss: tensor(158.4724, grad_fn=<AddBackward0>)
# loss: tensor(156.0994, grad_fn=<AddBackward0>)
# loss: tensor(153.7718, grad_fn=<AddBackward0>)
# loss: tensor(151.4899, grad_fn=<AddBackward0>)
# loss: tensor(149.2538, grad_fn=<AddBackward0>)
# loss: tensor(147.0626, grad_fn=<AddBackward0>)
# loss: tensor(144.9150, grad_fn=<AddBackward0>)
# loss: tensor(142.8095, grad_fn=<AddBackward0>)
# loss: tensor(140.7447, grad_fn=<AddBackward0>)
# loss: tensor(138.7193, grad_fn=<AddBackward0>)
# loss: tensor(136.7321, grad_fn=<AddBackward0>)
# loss: tensor(134.7821, grad_fn=<AddBackward0>)
# loss: tensor(132.8682, grad_fn=<AddBackward0>)
# loss: tensor(130.9889, grad_fn=<AddBackward0>)
# loss: tensor(129.1426, grad_fn=<AddBackward0>)
# loss: tensor(127.3274, grad_fn=<AddBackward0>)
# loss: tensor(125.5418, grad_fn=<AddBackward0>)
# loss: tensor(123.7845, grad_fn=<AddBackward0>)
# loss: tensor(122.0545, grad_fn=<AddBackward0>)
# loss: tensor(120.3512, grad_fn=<AddBackward0>)
# loss: tensor(118.6740, grad_fn=<AddBackward0>)
# loss: tensor(117.0222, grad_fn=<AddBackward0>)
# loss: tensor(115.3949, grad_fn=<AddBackward0>)
# loss: tensor(113.7910, grad_fn=<AddBackward0>)
# loss: tensor(112.2093, grad_fn=<AddBackward0>)
# loss: tensor(110.6485, grad_fn=<AddBackward0>)
# loss: tensor(109.1075, grad_fn=<AddBackward0>)
# loss: tensor(107.5851, grad_fn=<AddBackward0>)
# loss: tensor(106.0803, grad_fn=<AddBackward0>)
# loss: tensor(104.5918, grad_fn=<AddBackward0>)
# loss: tensor(103.1184, grad_fn=<AddBackward0>)
# loss: tensor(101.6588, grad_fn=<AddBackward0>)
# loss: tensor(100.2118, grad_fn=<AddBackward0>)
# loss: tensor(98.7764, grad_fn=<AddBackward0>)
# loss: tensor(97.3518, grad_fn=<AddBackward0>)
# loss: tensor(95.9374, grad_fn=<AddBackward0>)
# loss: tensor(94.5330, grad_fn=<AddBackward0>)
# loss: tensor(93.1388, grad_fn=<AddBackward0>)
# loss: tensor(91.7548, grad_fn=<AddBackward0>)
# loss: tensor(90.3818, grad_fn=<AddBackward0>)
# loss: tensor(89.0207, grad_fn=<AddBackward0>)
# loss: tensor(87.6725, grad_fn=<AddBackward0>)
# loss: tensor(86.3388, grad_fn=<AddBackward0>)
# loss: tensor(85.0213, grad_fn=<AddBackward0>)
# loss: tensor(83.7218, grad_fn=<AddBackward0>)
# loss: tensor(82.4423, grad_fn=<AddBackward0>)
# loss: tensor(81.1844, grad_fn=<AddBackward0>)
# loss: tensor(79.9494, grad_fn=<AddBackward0>)
# loss: tensor(78.7384, grad_fn=<AddBackward0>)
# loss: tensor(77.5519, grad_fn=<AddBackward0>)
# loss: tensor(76.3900, grad_fn=<AddBackward0>)
# loss: tensor(75.2522, grad_fn=<AddBackward0>)
# loss: tensor(74.1378, grad_fn=<AddBackward0>)
# loss: tensor(73.0456, grad_fn=<AddBackward0>)
# loss: tensor(71.9745, grad_fn=<AddBackward0>)
# loss: tensor(70.9231, grad_fn=<AddBackward0>)
# loss: tensor(69.8903, grad_fn=<AddBackward0>)
# loss: tensor(68.8749, grad_fn=<AddBackward0>)
# loss: tensor(67.8756, grad_fn=<AddBackward0>)
# loss: tensor(66.8915, grad_fn=<AddBackward0>)
# loss: tensor(65.9213, grad_fn=<AddBackward0>)
# loss: tensor(64.9638, grad_fn=<AddBackward0>)
# loss: tensor(64.0177, grad_fn=<AddBackward0>)
# loss: tensor(63.0815, grad_fn=<AddBackward0>)
# loss: tensor(62.1533, grad_fn=<AddBackward0>)
# loss: tensor(61.2315, grad_fn=<AddBackward0>)
# loss: tensor(60.3141, grad_fn=<AddBackward0>)
# loss: tensor(59.3995, grad_fn=<AddBackward0>)
# loss: tensor(58.4862, grad_fn=<AddBackward0>)
# loss: tensor(57.5736, grad_fn=<AddBackward0>)
# loss: tensor(56.6615, grad_fn=<AddBackward0>)
# loss: tensor(55.7512, grad_fn=<AddBackward0>)
# loss: tensor(54.8449, grad_fn=<AddBackward0>)
# loss: tensor(53.9461, grad_fn=<AddBackward0>)
# loss: tensor(53.0591, grad_fn=<AddBackward0>)
# loss: tensor(52.1879, grad_fn=<AddBackward0>)
# loss: tensor(51.3361, grad_fn=<AddBackward0>)
# loss: tensor(50.5055, grad_fn=<AddBackward0>)
# loss: tensor(49.6964, grad_fn=<AddBackward0>)
# loss: tensor(48.9080, grad_fn=<AddBackward0>)
# loss: tensor(48.1395, grad_fn=<AddBackward0>)
# loss: tensor(47.3902, grad_fn=<AddBackward0>)
# loss: tensor(46.6602, grad_fn=<AddBackward0>)
# loss: tensor(45.9493, grad_fn=<AddBackward0>)
# loss: tensor(45.2569, grad_fn=<AddBackward0>)
# loss: tensor(44.5820, grad_fn=<AddBackward0>)
# loss: tensor(43.9223, grad_fn=<AddBackward0>)
# loss: tensor(43.2757, grad_fn=<AddBackward0>)
# loss: tensor(42.6399, grad_fn=<AddBackward0>)
# step=200 - loss=42.6399
# loss: tensor(42.0132, grad_fn=<AddBackward0>)
# loss: tensor(41.3945, grad_fn=<AddBackward0>)
# loss: tensor(40.7836, grad_fn=<AddBackward0>)
# loss: tensor(40.1809, grad_fn=<AddBackward0>)
# loss: tensor(39.5872, grad_fn=<AddBackward0>)
# loss: tensor(39.0034, grad_fn=<AddBackward0>)
# loss: tensor(38.4302, grad_fn=<AddBackward0>)
# loss: tensor(37.8681, grad_fn=<AddBackward0>)
# loss: tensor(37.3173, grad_fn=<AddBackward0>)
# loss: tensor(36.7777, grad_fn=<AddBackward0>)
# loss: tensor(36.2491, grad_fn=<AddBackward0>)
# loss: tensor(35.7314, grad_fn=<AddBackward0>)
# loss: tensor(35.2244, grad_fn=<AddBackward0>)
# loss: tensor(34.7279, grad_fn=<AddBackward0>)
# loss: tensor(34.2419, grad_fn=<AddBackward0>)
# loss: tensor(33.7662, grad_fn=<AddBackward0>)
# loss: tensor(33.3005, grad_fn=<AddBackward0>)
# loss: tensor(32.8448, grad_fn=<AddBackward0>)
# loss: tensor(32.3986, grad_fn=<AddBackward0>)
# loss: tensor(31.9617, grad_fn=<AddBackward0>)
# loss: tensor(31.5338, grad_fn=<AddBackward0>)
# loss: tensor(31.1145, grad_fn=<AddBackward0>)
# loss: tensor(30.7034, grad_fn=<AddBackward0>)
# loss: tensor(30.3001, grad_fn=<AddBackward0>)
# loss: tensor(29.9042, grad_fn=<AddBackward0>)
# loss: tensor(29.5155, grad_fn=<AddBackward0>)
# loss: tensor(29.1337, grad_fn=<AddBackward0>)
# loss: tensor(28.7586, grad_fn=<AddBackward0>)
# loss: tensor(28.3900, grad_fn=<AddBackward0>)
# loss: tensor(28.0277, grad_fn=<AddBackward0>)
# loss: tensor(27.6717, grad_fn=<AddBackward0>)
# loss: tensor(27.3220, grad_fn=<AddBackward0>)
# loss: tensor(26.9784, grad_fn=<AddBackward0>)
# loss: tensor(26.6410, grad_fn=<AddBackward0>)
# loss: tensor(26.3097, grad_fn=<AddBackward0>)
# loss: tensor(25.9844, grad_fn=<AddBackward0>)
# loss: tensor(25.6650, grad_fn=<AddBackward0>)
# loss: tensor(25.3515, grad_fn=<AddBackward0>)
# loss: tensor(25.0436, grad_fn=<AddBackward0>)
# loss: tensor(24.7414, grad_fn=<AddBackward0>)
# loss: tensor(24.4445, grad_fn=<AddBackward0>)
# loss: tensor(24.1529, grad_fn=<AddBackward0>)
# loss: tensor(23.8665, grad_fn=<AddBackward0>)
# loss: tensor(23.5851, grad_fn=<AddBackward0>)
# loss: tensor(23.3086, grad_fn=<AddBackward0>)
# loss: tensor(23.0370, grad_fn=<AddBackward0>)
# loss: tensor(22.7702, grad_fn=<AddBackward0>)
# loss: tensor(22.5080, grad_fn=<AddBackward0>)
# loss: tensor(22.2503, grad_fn=<AddBackward0>)
# loss: tensor(21.9972, grad_fn=<AddBackward0>)
# loss: tensor(21.7484, grad_fn=<AddBackward0>)
# loss: tensor(21.5041, grad_fn=<AddBackward0>)
# loss: tensor(21.2640, grad_fn=<AddBackward0>)
# loss: tensor(21.0281, grad_fn=<AddBackward0>)
# loss: tensor(20.7963, grad_fn=<AddBackward0>)
# loss: tensor(20.5686, grad_fn=<AddBackward0>)
# loss: tensor(20.3448, grad_fn=<AddBackward0>)
# loss: tensor(20.1248, grad_fn=<AddBackward0>)
# loss: tensor(19.9087, grad_fn=<AddBackward0>)
# loss: tensor(19.6963, grad_fn=<AddBackward0>)
# loss: tensor(19.4875, grad_fn=<AddBackward0>)
# loss: tensor(19.2823, grad_fn=<AddBackward0>)
# loss: tensor(19.0806, grad_fn=<AddBackward0>)
# loss: tensor(18.8823, grad_fn=<AddBackward0>)
# loss: tensor(18.6874, grad_fn=<AddBackward0>)
# loss: tensor(18.4958, grad_fn=<AddBackward0>)
# loss: tensor(18.3074, grad_fn=<AddBackward0>)
# loss: tensor(18.1222, grad_fn=<AddBackward0>)
# loss: tensor(17.9400, grad_fn=<AddBackward0>)
# loss: tensor(17.7609, grad_fn=<AddBackward0>)
# loss: tensor(17.5848, grad_fn=<AddBackward0>)
# loss: tensor(17.4116, grad_fn=<AddBackward0>)
# loss: tensor(17.2413, grad_fn=<AddBackward0>)
# loss: tensor(17.0738, grad_fn=<AddBackward0>)
# loss: tensor(16.9091, grad_fn=<AddBackward0>)
# loss: tensor(16.7471, grad_fn=<AddBackward0>)
# loss: tensor(16.5877, grad_fn=<AddBackward0>)
# loss: tensor(16.4310, grad_fn=<AddBackward0>)
# loss: tensor(16.2768, grad_fn=<AddBackward0>)
# loss: tensor(16.1251, grad_fn=<AddBackward0>)
# loss: tensor(15.9759, grad_fn=<AddBackward0>)
# loss: tensor(15.8292, grad_fn=<AddBackward0>)
# loss: tensor(15.6848, grad_fn=<AddBackward0>)
# loss: tensor(15.5427, grad_fn=<AddBackward0>)
# loss: tensor(15.4029, grad_fn=<AddBackward0>)
# loss: tensor(15.2653, grad_fn=<AddBackward0>)
# loss: tensor(15.1299, grad_fn=<AddBackward0>)
# loss: tensor(14.9967, grad_fn=<AddBackward0>)
# loss: tensor(14.8655, grad_fn=<AddBackward0>)
# loss: tensor(14.7365, grad_fn=<AddBackward0>)
# loss: tensor(14.6095, grad_fn=<AddBackward0>)
# loss: tensor(14.4845, grad_fn=<AddBackward0>)
# loss: tensor(14.3614, grad_fn=<AddBackward0>)
# loss: tensor(14.2403, grad_fn=<AddBackward0>)
# loss: tensor(14.1210, grad_fn=<AddBackward0>)
# loss: tensor(14.0036, grad_fn=<AddBackward0>)
# loss: tensor(13.8880, grad_fn=<AddBackward0>)
# loss: tensor(13.7742, grad_fn=<AddBackward0>)
# loss: tensor(13.6622, grad_fn=<AddBackward0>)
# loss: tensor(13.5518, grad_fn=<AddBackward0>)
# step=300 - loss=13.5518
# loss: tensor(13.4432, grad_fn=<AddBackward0>)
# loss: tensor(13.3362, grad_fn=<AddBackward0>)
# loss: tensor(13.2308, grad_fn=<AddBackward0>)
# loss: tensor(13.1270, grad_fn=<AddBackward0>)
# loss: tensor(13.0248, grad_fn=<AddBackward0>)
# loss: tensor(12.9241, grad_fn=<AddBackward0>)
# loss: tensor(12.8250, grad_fn=<AddBackward0>)
# loss: tensor(12.7273, grad_fn=<AddBackward0>)
# loss: tensor(12.6310, grad_fn=<AddBackward0>)
# loss: tensor(12.5362, grad_fn=<AddBackward0>)
# loss: tensor(12.4428, grad_fn=<AddBackward0>)
# loss: tensor(12.3508, grad_fn=<AddBackward0>)
# loss: tensor(12.2601, grad_fn=<AddBackward0>)
# loss: tensor(12.1708, grad_fn=<AddBackward0>)
# loss: tensor(12.0827, grad_fn=<AddBackward0>)
# loss: tensor(11.9960, grad_fn=<AddBackward0>)
# loss: tensor(11.9105, grad_fn=<AddBackward0>)
# loss: tensor(11.8262, grad_fn=<AddBackward0>)
# loss: tensor(11.7431, grad_fn=<AddBackward0>)
# loss: tensor(11.6613, grad_fn=<AddBackward0>)
# loss: tensor(11.5806, grad_fn=<AddBackward0>)
# loss: tensor(11.5010, grad_fn=<AddBackward0>)
# loss: tensor(11.4226, grad_fn=<AddBackward0>)
# loss: tensor(11.3453, grad_fn=<AddBackward0>)
# loss: tensor(11.2691, grad_fn=<AddBackward0>)
# loss: tensor(11.1939, grad_fn=<AddBackward0>)
# loss: tensor(11.1198, grad_fn=<AddBackward0>)
# loss: tensor(11.0467, grad_fn=<AddBackward0>)
# loss: tensor(10.9747, grad_fn=<AddBackward0>)
# loss: tensor(10.9036, grad_fn=<AddBackward0>)
# loss: tensor(10.8335, grad_fn=<AddBackward0>)
# loss: tensor(10.7644, grad_fn=<AddBackward0>)
# loss: tensor(10.6961, grad_fn=<AddBackward0>)
# loss: tensor(10.6289, grad_fn=<AddBackward0>)
# loss: tensor(10.5625, grad_fn=<AddBackward0>)
# loss: tensor(10.4970, grad_fn=<AddBackward0>)
# loss: tensor(10.4323, grad_fn=<AddBackward0>)
# loss: tensor(10.3685, grad_fn=<AddBackward0>)
# loss: tensor(10.3056, grad_fn=<AddBackward0>)
# loss: tensor(10.2435, grad_fn=<AddBackward0>)
# loss: tensor(10.1821, grad_fn=<AddBackward0>)
# loss: tensor(10.1215, grad_fn=<AddBackward0>)
# loss: tensor(10.0617, grad_fn=<AddBackward0>)
# loss: tensor(10.0027, grad_fn=<AddBackward0>)
# loss: tensor(9.9443, grad_fn=<AddBackward0>)
# loss: tensor(9.8867, grad_fn=<AddBackward0>)
# loss: tensor(9.8297, grad_fn=<AddBackward0>)
# loss: tensor(9.7734, grad_fn=<AddBackward0>)
# loss: tensor(9.7178, grad_fn=<AddBackward0>)
# loss: tensor(9.6628, grad_fn=<AddBackward0>)
# loss: tensor(9.6084, grad_fn=<AddBackward0>)
# loss: tensor(9.5546, grad_fn=<AddBackward0>)
# loss: tensor(9.5015, grad_fn=<AddBackward0>)
# loss: tensor(9.4489, grad_fn=<AddBackward0>)
# loss: tensor(9.3969, grad_fn=<AddBackward0>)
# loss: tensor(9.3454, grad_fn=<AddBackward0>)
# loss: tensor(9.2945, grad_fn=<AddBackward0>)
# loss: tensor(9.2442, grad_fn=<AddBackward0>)
# loss: tensor(9.1944, grad_fn=<AddBackward0>)
# loss: tensor(9.1451, grad_fn=<AddBackward0>)
# loss: tensor(9.0964, grad_fn=<AddBackward0>)
# loss: tensor(9.0482, grad_fn=<AddBackward0>)
# loss: tensor(9.0005, grad_fn=<AddBackward0>)
# loss: tensor(8.9534, grad_fn=<AddBackward0>)
# loss: tensor(8.9067, grad_fn=<AddBackward0>)
# loss: tensor(8.8605, grad_fn=<AddBackward0>)
# loss: tensor(8.8149, grad_fn=<AddBackward0>)
# loss: tensor(8.7697, grad_fn=<AddBackward0>)
# loss: tensor(8.7249, grad_fn=<AddBackward0>)
# loss: tensor(8.6806, grad_fn=<AddBackward0>)
# loss: tensor(8.6367, grad_fn=<AddBackward0>)
# loss: tensor(8.5933, grad_fn=<AddBackward0>)
# loss: tensor(8.5502, grad_fn=<AddBackward0>)
# loss: tensor(8.5075, grad_fn=<AddBackward0>)
# loss: tensor(8.4652, grad_fn=<AddBackward0>)
# loss: tensor(8.4233, grad_fn=<AddBackward0>)
# loss: tensor(8.3817, grad_fn=<AddBackward0>)
# loss: tensor(8.3405, grad_fn=<AddBackward0>)
# loss: tensor(8.2996, grad_fn=<AddBackward0>)
# loss: tensor(8.2591, grad_fn=<AddBackward0>)
# loss: tensor(8.2189, grad_fn=<AddBackward0>)
# loss: tensor(8.1791, grad_fn=<AddBackward0>)
# loss: tensor(8.1398, grad_fn=<AddBackward0>)
# loss: tensor(8.1008, grad_fn=<AddBackward0>)
# loss: tensor(8.0624, grad_fn=<AddBackward0>)
# loss: tensor(8.0244, grad_fn=<AddBackward0>)
# loss: tensor(7.9868, grad_fn=<AddBackward0>)
# loss: tensor(7.9498, grad_fn=<AddBackward0>)
# loss: tensor(7.9133, grad_fn=<AddBackward0>)
# loss: tensor(7.8773, grad_fn=<AddBackward0>)
# loss: tensor(7.8419, grad_fn=<AddBackward0>)
# loss: tensor(7.8070, grad_fn=<AddBackward0>)
# loss: tensor(7.7726, grad_fn=<AddBackward0>)
# loss: tensor(7.7387, grad_fn=<AddBackward0>)
# loss: tensor(7.7053, grad_fn=<AddBackward0>)
# loss: tensor(7.6724, grad_fn=<AddBackward0>)
# loss: tensor(7.6398, grad_fn=<AddBackward0>)
# loss: tensor(7.6077, grad_fn=<AddBackward0>)
# loss: tensor(7.5760, grad_fn=<AddBackward0>)
# loss: tensor(7.5446, grad_fn=<AddBackward0>)
# step=400 - loss=7.5446
# loss: tensor(7.5136, grad_fn=<AddBackward0>)
# loss: tensor(7.4829, grad_fn=<AddBackward0>)
# loss: tensor(7.4526, grad_fn=<AddBackward0>)
# loss: tensor(7.4226, grad_fn=<AddBackward0>)
# loss: tensor(7.3929, grad_fn=<AddBackward0>)
# loss: tensor(7.3635, grad_fn=<AddBackward0>)
# loss: tensor(7.3344, grad_fn=<AddBackward0>)
# loss: tensor(7.3057, grad_fn=<AddBackward0>)
# loss: tensor(7.2772, grad_fn=<AddBackward0>)
# loss: tensor(7.2491, grad_fn=<AddBackward0>)
# loss: tensor(7.2212, grad_fn=<AddBackward0>)
# loss: tensor(7.1937, grad_fn=<AddBackward0>)
# loss: tensor(7.1665, grad_fn=<AddBackward0>)
# loss: tensor(7.1396, grad_fn=<AddBackward0>)
# loss: tensor(7.1129, grad_fn=<AddBackward0>)
# loss: tensor(7.0866, grad_fn=<AddBackward0>)
# loss: tensor(7.0605, grad_fn=<AddBackward0>)
# loss: tensor(7.0348, grad_fn=<AddBackward0>)
# loss: tensor(7.0093, grad_fn=<AddBackward0>)
# loss: tensor(6.9841, grad_fn=<AddBackward0>)
# loss: tensor(6.9592, grad_fn=<AddBackward0>)
# loss: tensor(6.9346, grad_fn=<AddBackward0>)
# loss: tensor(6.9103, grad_fn=<AddBackward0>)
# loss: tensor(6.8862, grad_fn=<AddBackward0>)
# loss: tensor(6.8624, grad_fn=<AddBackward0>)
# loss: tensor(6.8388, grad_fn=<AddBackward0>)
# loss: tensor(6.8155, grad_fn=<AddBackward0>)
# loss: tensor(6.7924, grad_fn=<AddBackward0>)
# loss: tensor(6.7696, grad_fn=<AddBackward0>)
# loss: tensor(6.7470, grad_fn=<AddBackward0>)
# loss: tensor(6.7247, grad_fn=<AddBackward0>)
# loss: tensor(6.7026, grad_fn=<AddBackward0>)
# loss: tensor(6.6808, grad_fn=<AddBackward0>)
# loss: tensor(6.6591, grad_fn=<AddBackward0>)
# loss: tensor(6.6377, grad_fn=<AddBackward0>)
# loss: tensor(6.6166, grad_fn=<AddBackward0>)
# loss: tensor(6.5956, grad_fn=<AddBackward0>)
# loss: tensor(6.5749, grad_fn=<AddBackward0>)
# loss: tensor(6.5544, grad_fn=<AddBackward0>)
# loss: tensor(6.5341, grad_fn=<AddBackward0>)
# loss: tensor(6.5140, grad_fn=<AddBackward0>)
# loss: tensor(6.4941, grad_fn=<AddBackward0>)
# loss: tensor(6.4745, grad_fn=<AddBackward0>)
# loss: tensor(6.4550, grad_fn=<AddBackward0>)
# loss: tensor(6.4357, grad_fn=<AddBackward0>)
# loss: tensor(6.4167, grad_fn=<AddBackward0>)
# loss: tensor(6.3978, grad_fn=<AddBackward0>)
# loss: tensor(6.3792, grad_fn=<AddBackward0>)
# loss: tensor(6.3607, grad_fn=<AddBackward0>)
# loss: tensor(6.3424, grad_fn=<AddBackward0>)
# loss: tensor(6.3243, grad_fn=<AddBackward0>)
# loss: tensor(6.3064, grad_fn=<AddBackward0>)
# loss: tensor(6.2886, grad_fn=<AddBackward0>)
# loss: tensor(6.2711, grad_fn=<AddBackward0>)
# loss: tensor(6.2537, grad_fn=<AddBackward0>)
# loss: tensor(6.2365, grad_fn=<AddBackward0>)
# loss: tensor(6.2195, grad_fn=<AddBackward0>)
# loss: tensor(6.2026, grad_fn=<AddBackward0>)
# loss: tensor(6.1859, grad_fn=<AddBackward0>)
# loss: tensor(6.1694, grad_fn=<AddBackward0>)
# loss: tensor(6.1530, grad_fn=<AddBackward0>)
# loss: tensor(6.1369, grad_fn=<AddBackward0>)
# loss: tensor(6.1208, grad_fn=<AddBackward0>)
# loss: tensor(6.1050, grad_fn=<AddBackward0>)
# loss: tensor(6.0892, grad_fn=<AddBackward0>)
# loss: tensor(6.0737, grad_fn=<AddBackward0>)
# loss: tensor(6.0583, grad_fn=<AddBackward0>)
# loss: tensor(6.0430, grad_fn=<AddBackward0>)
# loss: tensor(6.0279, grad_fn=<AddBackward0>)
# loss: tensor(6.0129, grad_fn=<AddBackward0>)
# loss: tensor(5.9981, grad_fn=<AddBackward0>)
# loss: tensor(5.9835, grad_fn=<AddBackward0>)
# loss: tensor(5.9689, grad_fn=<AddBackward0>)
# loss: tensor(5.9545, grad_fn=<AddBackward0>)
# loss: tensor(5.9403, grad_fn=<AddBackward0>)
# loss: tensor(5.9262, grad_fn=<AddBackward0>)
# loss: tensor(5.9122, grad_fn=<AddBackward0>)
# loss: tensor(5.8984, grad_fn=<AddBackward0>)
# loss: tensor(5.8847, grad_fn=<AddBackward0>)
# loss: tensor(5.8711, grad_fn=<AddBackward0>)
# loss: tensor(5.8576, grad_fn=<AddBackward0>)
# loss: tensor(5.8443, grad_fn=<AddBackward0>)
# loss: tensor(5.8311, grad_fn=<AddBackward0>)
# loss: tensor(5.8180, grad_fn=<AddBackward0>)
# loss: tensor(5.8051, grad_fn=<AddBackward0>)
# loss: tensor(5.7923, grad_fn=<AddBackward0>)
# loss: tensor(5.7796, grad_fn=<AddBackward0>)
# loss: tensor(5.7670, grad_fn=<AddBackward0>)
# loss: tensor(5.7545, grad_fn=<AddBackward0>)
# loss: tensor(5.7421, grad_fn=<AddBackward0>)
# loss: tensor(5.7299, grad_fn=<AddBackward0>)
# loss: tensor(5.7178, grad_fn=<AddBackward0>)
# loss: tensor(5.7058, grad_fn=<AddBackward0>)
# loss: tensor(5.6938, grad_fn=<AddBackward0>)
# loss: tensor(5.6821, grad_fn=<AddBackward0>)
# loss: tensor(5.6704, grad_fn=<AddBackward0>)
# loss: tensor(5.6588, grad_fn=<AddBackward0>)
# loss: tensor(5.6473, grad_fn=<AddBackward0>)
# loss: tensor(5.6359, grad_fn=<AddBackward0>)
# loss: tensor(1019.4088, grad_fn=<AddBackward0>)
# step=0 - loss=1019.4088
# loss: tensor(931.5350, grad_fn=<AddBackward0>)
# loss: tensor(846.9664, grad_fn=<AddBackward0>)
# loss: tensor(765.8699, grad_fn=<AddBackward0>)
# loss: tensor(688.7756, grad_fn=<AddBackward0>)
# loss: tensor(616.2964, grad_fn=<AddBackward0>)
# loss: tensor(549.0508, grad_fn=<AddBackward0>)
# loss: tensor(487.5242, grad_fn=<AddBackward0>)
# loss: tensor(432.1149, grad_fn=<AddBackward0>)
# loss: tensor(383.1126, grad_fn=<AddBackward0>)
# loss: tensor(340.6720, grad_fn=<AddBackward0>)
# loss: tensor(304.7456, grad_fn=<AddBackward0>)
# loss: tensor(274.9936, grad_fn=<AddBackward0>)
# loss: tensor(250.7301, grad_fn=<AddBackward0>)
# loss: tensor(230.9711, grad_fn=<AddBackward0>)
# loss: tensor(214.5983, grad_fn=<AddBackward0>)
# loss: tensor(200.5678, grad_fn=<AddBackward0>)
# loss: tensor(188.0529, grad_fn=<AddBackward0>)
# loss: tensor(176.4665, grad_fn=<AddBackward0>)
# loss: tensor(165.3957, grad_fn=<AddBackward0>)
# loss: tensor(154.5910, grad_fn=<AddBackward0>)
# loss: tensor(144.0055, grad_fn=<AddBackward0>)
# loss: tensor(133.7475, grad_fn=<AddBackward0>)
# loss: tensor(123.9981, grad_fn=<AddBackward0>)
# loss: tensor(114.9501, grad_fn=<AddBackward0>)
# loss: tensor(106.7657, grad_fn=<AddBackward0>)
# loss: tensor(99.5477, grad_fn=<AddBackward0>)
# loss: tensor(93.3247, grad_fn=<AddBackward0>)
# loss: tensor(88.0492, grad_fn=<AddBackward0>)
# loss: tensor(83.6127, grad_fn=<AddBackward0>)
# loss: tensor(79.8709, grad_fn=<AddBackward0>)
# loss: tensor(76.6703, grad_fn=<AddBackward0>)
# loss: tensor(73.8661, grad_fn=<AddBackward0>)
# loss: tensor(71.3318, grad_fn=<AddBackward0>)
# loss: tensor(68.9644, grad_fn=<AddBackward0>)
# loss: tensor(66.6870, grad_fn=<AddBackward0>)
# loss: tensor(64.4488, grad_fn=<AddBackward0>)
# loss: tensor(62.2251, grad_fn=<AddBackward0>)
# loss: tensor(60.0153, grad_fn=<AddBackward0>)
# loss: tensor(57.8397, grad_fn=<AddBackward0>)
# loss: tensor(55.7340, grad_fn=<AddBackward0>)
# loss: tensor(53.7387, grad_fn=<AddBackward0>)
# loss: tensor(51.8879, grad_fn=<AddBackward0>)
# loss: tensor(50.1991, grad_fn=<AddBackward0>)
# loss: tensor(48.6683, grad_fn=<AddBackward0>)
# loss: tensor(47.2725, grad_fn=<AddBackward0>)
# loss: tensor(45.9782, grad_fn=<AddBackward0>)
# loss: tensor(44.7524, grad_fn=<AddBackward0>)
# loss: tensor(43.5701, grad_fn=<AddBackward0>)
# loss: tensor(42.4154, grad_fn=<AddBackward0>)
# loss: tensor(41.2794, grad_fn=<AddBackward0>)
# loss: tensor(40.1577, grad_fn=<AddBackward0>)
# loss: tensor(39.0494, grad_fn=<AddBackward0>)
# loss: tensor(37.9598, grad_fn=<AddBackward0>)
# loss: tensor(36.9008, grad_fn=<AddBackward0>)
# loss: tensor(35.8878, grad_fn=<AddBackward0>)
# loss: tensor(34.9337, grad_fn=<AddBackward0>)
# loss: tensor(34.0437, grad_fn=<AddBackward0>)
# loss: tensor(33.2141, grad_fn=<AddBackward0>)
# loss: tensor(32.4349, grad_fn=<AddBackward0>)
# loss: tensor(31.6953, grad_fn=<AddBackward0>)
# loss: tensor(30.9870, grad_fn=<AddBackward0>)
# loss: tensor(30.3052, grad_fn=<AddBackward0>)
# loss: tensor(29.6469, grad_fn=<AddBackward0>)
# loss: tensor(29.0098, grad_fn=<AddBackward0>)
# loss: tensor(28.3917, grad_fn=<AddBackward0>)
# loss: tensor(27.7922, grad_fn=<AddBackward0>)
# loss: tensor(27.2125, grad_fn=<AddBackward0>)
# loss: tensor(26.6547, grad_fn=<AddBackward0>)
# loss: tensor(26.1195, grad_fn=<AddBackward0>)
# loss: tensor(25.6049, grad_fn=<AddBackward0>)
# loss: tensor(25.1067, grad_fn=<AddBackward0>)
# loss: tensor(24.6204, grad_fn=<AddBackward0>)
# loss: tensor(24.1432, grad_fn=<AddBackward0>)
# loss: tensor(23.6744, grad_fn=<AddBackward0>)
# loss: tensor(23.2147, grad_fn=<AddBackward0>)
# loss: tensor(22.7651, grad_fn=<AddBackward0>)
# loss: tensor(22.3265, grad_fn=<AddBackward0>)
# loss: tensor(21.9002, grad_fn=<AddBackward0>)
# loss: tensor(21.4880, grad_fn=<AddBackward0>)
# loss: tensor(21.0912, grad_fn=<AddBackward0>)
# loss: tensor(20.7103, grad_fn=<AddBackward0>)
# loss: tensor(20.3440, grad_fn=<AddBackward0>)
# loss: tensor(19.9904, grad_fn=<AddBackward0>)
# loss: tensor(19.6477, grad_fn=<AddBackward0>)
# loss: tensor(19.3144, grad_fn=<AddBackward0>)
# loss: tensor(18.9899, grad_fn=<AddBackward0>)
# loss: tensor(18.6734, grad_fn=<AddBackward0>)
# loss: tensor(18.3643, grad_fn=<AddBackward0>)
# loss: tensor(18.0622, grad_fn=<AddBackward0>)
# loss: tensor(17.7675, grad_fn=<AddBackward0>)
# loss: tensor(17.4803, grad_fn=<AddBackward0>)
# loss: tensor(17.2011, grad_fn=<AddBackward0>)
# loss: tensor(16.9298, grad_fn=<AddBackward0>)
# loss: tensor(16.6659, grad_fn=<AddBackward0>)
# loss: tensor(16.4093, grad_fn=<AddBackward0>)
# loss: tensor(16.1596, grad_fn=<AddBackward0>)
# loss: tensor(15.9167, grad_fn=<AddBackward0>)
# loss: tensor(15.6802, grad_fn=<AddBackward0>)
# loss: tensor(15.4498, grad_fn=<AddBackward0>)
# loss: tensor(15.2251, grad_fn=<AddBackward0>)
# step=100 - loss=15.2251
# loss: tensor(15.0059, grad_fn=<AddBackward0>)
# loss: tensor(14.7923, grad_fn=<AddBackward0>)
# loss: tensor(14.5840, grad_fn=<AddBackward0>)
# loss: tensor(14.3807, grad_fn=<AddBackward0>)
# loss: tensor(14.1822, grad_fn=<AddBackward0>)
# loss: tensor(13.9883, grad_fn=<AddBackward0>)
# loss: tensor(13.7987, grad_fn=<AddBackward0>)
# loss: tensor(13.6132, grad_fn=<AddBackward0>)
# loss: tensor(13.4316, grad_fn=<AddBackward0>)
# loss: tensor(13.2535, grad_fn=<AddBackward0>)
# loss: tensor(13.0789, grad_fn=<AddBackward0>)
# loss: tensor(12.9077, grad_fn=<AddBackward0>)
# loss: tensor(12.7398, grad_fn=<AddBackward0>)
# loss: tensor(12.5751, grad_fn=<AddBackward0>)
# loss: tensor(12.4135, grad_fn=<AddBackward0>)
# loss: tensor(12.2548, grad_fn=<AddBackward0>)
# loss: tensor(12.0989, grad_fn=<AddBackward0>)
# loss: tensor(11.9457, grad_fn=<AddBackward0>)
# loss: tensor(11.7950, grad_fn=<AddBackward0>)
# loss: tensor(11.6465, grad_fn=<AddBackward0>)
# loss: tensor(11.5002, grad_fn=<AddBackward0>)
# loss: tensor(11.3560, grad_fn=<AddBackward0>)
# loss: tensor(11.2137, grad_fn=<AddBackward0>)
# loss: tensor(11.0733, grad_fn=<AddBackward0>)
# loss: tensor(10.9348, grad_fn=<AddBackward0>)
# loss: tensor(10.7981, grad_fn=<AddBackward0>)
# loss: tensor(10.6632, grad_fn=<AddBackward0>)
# loss: tensor(10.5301, grad_fn=<AddBackward0>)
# loss: tensor(10.3986, grad_fn=<AddBackward0>)
# loss: tensor(10.2687, grad_fn=<AddBackward0>)
# loss: tensor(10.1405, grad_fn=<AddBackward0>)
# loss: tensor(10.0139, grad_fn=<AddBackward0>)
# loss: tensor(9.8889, grad_fn=<AddBackward0>)
# loss: tensor(9.7655, grad_fn=<AddBackward0>)
# loss: tensor(9.6438, grad_fn=<AddBackward0>)
# loss: tensor(9.5237, grad_fn=<AddBackward0>)
# loss: tensor(9.4052, grad_fn=<AddBackward0>)
# loss: tensor(9.2884, grad_fn=<AddBackward0>)
# loss: tensor(9.1732, grad_fn=<AddBackward0>)
# loss: tensor(9.0596, grad_fn=<AddBackward0>)
# loss: tensor(8.9476, grad_fn=<AddBackward0>)
# loss: tensor(8.8373, grad_fn=<AddBackward0>)
# loss: tensor(8.7286, grad_fn=<AddBackward0>)
# loss: tensor(8.6215, grad_fn=<AddBackward0>)
# loss: tensor(8.5161, grad_fn=<AddBackward0>)
# loss: tensor(8.4123, grad_fn=<AddBackward0>)
# loss: tensor(8.3100, grad_fn=<AddBackward0>)
# loss: tensor(8.2094, grad_fn=<AddBackward0>)
# loss: tensor(8.1102, grad_fn=<AddBackward0>)
# loss: tensor(8.0126, grad_fn=<AddBackward0>)
# loss: tensor(7.9165, grad_fn=<AddBackward0>)
# loss: tensor(7.8218, grad_fn=<AddBackward0>)
# loss: tensor(7.7285, grad_fn=<AddBackward0>)
# loss: tensor(7.6366, grad_fn=<AddBackward0>)
# loss: tensor(7.5462, grad_fn=<AddBackward0>)
# loss: tensor(7.4571, grad_fn=<AddBackward0>)
# loss: tensor(7.3693, grad_fn=<AddBackward0>)
# loss: tensor(7.2828, grad_fn=<AddBackward0>)
# loss: tensor(7.1977, grad_fn=<AddBackward0>)
# loss: tensor(7.1138, grad_fn=<AddBackward0>)
# loss: tensor(7.0312, grad_fn=<AddBackward0>)
# loss: tensor(6.9498, grad_fn=<AddBackward0>)
# loss: tensor(6.8696, grad_fn=<AddBackward0>)
# loss: tensor(6.7906, grad_fn=<AddBackward0>)
# loss: tensor(6.7128, grad_fn=<AddBackward0>)
# loss: tensor(6.6362, grad_fn=<AddBackward0>)
# loss: tensor(6.5607, grad_fn=<AddBackward0>)
# loss: tensor(6.4864, grad_fn=<AddBackward0>)
# loss: tensor(6.4132, grad_fn=<AddBackward0>)
# loss: tensor(6.3412, grad_fn=<AddBackward0>)
# loss: tensor(6.2702, grad_fn=<AddBackward0>)
# loss: tensor(6.2003, grad_fn=<AddBackward0>)
# loss: tensor(6.1316, grad_fn=<AddBackward0>)
# loss: tensor(6.0638, grad_fn=<AddBackward0>)
# loss: tensor(5.9972, grad_fn=<AddBackward0>)
# loss: tensor(5.9316, grad_fn=<AddBackward0>)
# loss: tensor(5.8670, grad_fn=<AddBackward0>)
# loss: tensor(5.8034, grad_fn=<AddBackward0>)
# loss: tensor(5.7408, grad_fn=<AddBackward0>)
# loss: tensor(5.6792, grad_fn=<AddBackward0>)
# loss: tensor(5.6185, grad_fn=<AddBackward0>)
# loss: tensor(5.5588, grad_fn=<AddBackward0>)
# loss: tensor(5.5001, grad_fn=<AddBackward0>)
# loss: tensor(5.4422, grad_fn=<AddBackward0>)
# loss: tensor(5.3853, grad_fn=<AddBackward0>)
# loss: tensor(5.3292, grad_fn=<AddBackward0>)
# loss: tensor(5.2740, grad_fn=<AddBackward0>)
# loss: tensor(5.2196, grad_fn=<AddBackward0>)
# loss: tensor(5.1661, grad_fn=<AddBackward0>)
# loss: tensor(5.1133, grad_fn=<AddBackward0>)
# loss: tensor(5.0614, grad_fn=<AddBackward0>)
# loss: tensor(5.0103, grad_fn=<AddBackward0>)
# loss: tensor(4.9600, grad_fn=<AddBackward0>)
# loss: tensor(4.9104, grad_fn=<AddBackward0>)
# loss: tensor(4.8615, grad_fn=<AddBackward0>)
# loss: tensor(4.8134, grad_fn=<AddBackward0>)
# loss: tensor(4.7660, grad_fn=<AddBackward0>)
# loss: tensor(4.7193, grad_fn=<AddBackward0>)
# loss: tensor(4.6733, grad_fn=<AddBackward0>)
# loss: tensor(4.6280, grad_fn=<AddBackward0>)
# step=200 - loss=4.6280
# loss: tensor(4.5834, grad_fn=<AddBackward0>)
# loss: tensor(4.5394, grad_fn=<AddBackward0>)
# loss: tensor(4.4960, grad_fn=<AddBackward0>)
# loss: tensor(4.4533, grad_fn=<AddBackward0>)
# loss: tensor(4.4112, grad_fn=<AddBackward0>)
# loss: tensor(4.3697, grad_fn=<AddBackward0>)
# loss: tensor(4.3288, grad_fn=<AddBackward0>)
# loss: tensor(4.2885, grad_fn=<AddBackward0>)
# loss: tensor(4.2487, grad_fn=<AddBackward0>)
# loss: tensor(4.2096, grad_fn=<AddBackward0>)
# loss: tensor(4.1709, grad_fn=<AddBackward0>)
# loss: tensor(4.1328, grad_fn=<AddBackward0>)
# loss: tensor(4.0953, grad_fn=<AddBackward0>)
# loss: tensor(4.0583, grad_fn=<AddBackward0>)
# loss: tensor(4.0217, grad_fn=<AddBackward0>)
# loss: tensor(3.9857, grad_fn=<AddBackward0>)
# loss: tensor(3.9502, grad_fn=<AddBackward0>)
# loss: tensor(3.9152, grad_fn=<AddBackward0>)
# loss: tensor(3.8806, grad_fn=<AddBackward0>)
# loss: tensor(3.8465, grad_fn=<AddBackward0>)
# loss: tensor(3.8129, grad_fn=<AddBackward0>)
# loss: tensor(3.7797, grad_fn=<AddBackward0>)
# loss: tensor(3.7470, grad_fn=<AddBackward0>)
# loss: tensor(3.7147, grad_fn=<AddBackward0>)
# loss: tensor(3.6828, grad_fn=<AddBackward0>)
# loss: tensor(3.6514, grad_fn=<AddBackward0>)
# loss: tensor(3.6204, grad_fn=<AddBackward0>)
# loss: tensor(3.5897, grad_fn=<AddBackward0>)
# loss: tensor(3.5595, grad_fn=<AddBackward0>)
# loss: tensor(3.5297, grad_fn=<AddBackward0>)
# loss: tensor(3.5002, grad_fn=<AddBackward0>)
# loss: tensor(3.4711, grad_fn=<AddBackward0>)
# loss: tensor(3.4424, grad_fn=<AddBackward0>)
# loss: tensor(3.4141, grad_fn=<AddBackward0>)
# loss: tensor(3.3861, grad_fn=<AddBackward0>)
# loss: tensor(3.3585, grad_fn=<AddBackward0>)
# loss: tensor(3.3312, grad_fn=<AddBackward0>)
# loss: tensor(3.3043, grad_fn=<AddBackward0>)
# loss: tensor(3.2777, grad_fn=<AddBackward0>)
# loss: tensor(3.2514, grad_fn=<AddBackward0>)
# loss: tensor(3.2255, grad_fn=<AddBackward0>)
# loss: tensor(3.1999, grad_fn=<AddBackward0>)
# loss: tensor(3.1746, grad_fn=<AddBackward0>)
# loss: tensor(3.1496, grad_fn=<AddBackward0>)
# loss: tensor(3.1249, grad_fn=<AddBackward0>)
# loss: tensor(3.1005, grad_fn=<AddBackward0>)
# loss: tensor(3.0764, grad_fn=<AddBackward0>)
# loss: tensor(3.0526, grad_fn=<AddBackward0>)
# loss: tensor(3.0290, grad_fn=<AddBackward0>)
# loss: tensor(3.0058, grad_fn=<AddBackward0>)
# loss: tensor(2.9828, grad_fn=<AddBackward0>)
# loss: tensor(2.9601, grad_fn=<AddBackward0>)
# loss: tensor(2.9377, grad_fn=<AddBackward0>)
# loss: tensor(2.9155, grad_fn=<AddBackward0>)
# loss: tensor(2.8936, grad_fn=<AddBackward0>)
# loss: tensor(2.8719, grad_fn=<AddBackward0>)
# loss: tensor(2.8505, grad_fn=<AddBackward0>)
# loss: tensor(2.8294, grad_fn=<AddBackward0>)
# loss: tensor(2.8085, grad_fn=<AddBackward0>)
# loss: tensor(2.7878, grad_fn=<AddBackward0>)
# loss: tensor(2.7673, grad_fn=<AddBackward0>)
# loss: tensor(2.7471, grad_fn=<AddBackward0>)
# loss: tensor(2.7271, grad_fn=<AddBackward0>)
# loss: tensor(2.7074, grad_fn=<AddBackward0>)
# loss: tensor(2.6878, grad_fn=<AddBackward0>)
# loss: tensor(2.6685, grad_fn=<AddBackward0>)
# loss: tensor(2.6494, grad_fn=<AddBackward0>)
# loss: tensor(2.6305, grad_fn=<AddBackward0>)
# loss: tensor(2.6118, grad_fn=<AddBackward0>)
# loss: tensor(2.5934, grad_fn=<AddBackward0>)
# loss: tensor(2.5751, grad_fn=<AddBackward0>)
# loss: tensor(2.5570, grad_fn=<AddBackward0>)
# loss: tensor(2.5391, grad_fn=<AddBackward0>)
# loss: tensor(2.5214, grad_fn=<AddBackward0>)
# loss: tensor(2.5039, grad_fn=<AddBackward0>)
# loss: tensor(2.4866, grad_fn=<AddBackward0>)
# loss: tensor(2.4695, grad_fn=<AddBackward0>)
# loss: tensor(2.4525, grad_fn=<AddBackward0>)
# loss: tensor(2.4358, grad_fn=<AddBackward0>)
# loss: tensor(2.4192, grad_fn=<AddBackward0>)
# loss: tensor(2.4028, grad_fn=<AddBackward0>)
# loss: tensor(2.3865, grad_fn=<AddBackward0>)
# loss: tensor(2.3704, grad_fn=<AddBackward0>)
# loss: tensor(2.3545, grad_fn=<AddBackward0>)
# loss: tensor(2.3388, grad_fn=<AddBackward0>)
# loss: tensor(2.3232, grad_fn=<AddBackward0>)
# loss: tensor(2.3078, grad_fn=<AddBackward0>)
# loss: tensor(2.2925, grad_fn=<AddBackward0>)
# loss: tensor(2.2774, grad_fn=<AddBackward0>)
# loss: tensor(2.2625, grad_fn=<AddBackward0>)
# loss: tensor(2.2477, grad_fn=<AddBackward0>)
# loss: tensor(2.2330, grad_fn=<AddBackward0>)
# loss: tensor(2.2185, grad_fn=<AddBackward0>)
# loss: tensor(2.2041, grad_fn=<AddBackward0>)
# loss: tensor(2.1899, grad_fn=<AddBackward0>)
# loss: tensor(2.1758, grad_fn=<AddBackward0>)
# loss: tensor(2.1619, grad_fn=<AddBackward0>)
# loss: tensor(2.1481, grad_fn=<AddBackward0>)
# loss: tensor(2.1344, grad_fn=<AddBackward0>)
# loss: tensor(2.1209, grad_fn=<AddBackward0>)
# step=300 - loss=2.1209
# loss: tensor(2.1075, grad_fn=<AddBackward0>)
# loss: tensor(2.0942, grad_fn=<AddBackward0>)
# loss: tensor(2.0811, grad_fn=<AddBackward0>)
# loss: tensor(2.0680, grad_fn=<AddBackward0>)
# loss: tensor(2.0552, grad_fn=<AddBackward0>)
# loss: tensor(2.0424, grad_fn=<AddBackward0>)
# loss: tensor(2.0297, grad_fn=<AddBackward0>)
# loss: tensor(2.0172, grad_fn=<AddBackward0>)
# loss: tensor(2.0048, grad_fn=<AddBackward0>)
# loss: tensor(1.9925, grad_fn=<AddBackward0>)
# loss: tensor(1.9803, grad_fn=<AddBackward0>)
# loss: tensor(1.9683, grad_fn=<AddBackward0>)
# loss: tensor(1.9563, grad_fn=<AddBackward0>)
# loss: tensor(1.9445, grad_fn=<AddBackward0>)
# loss: tensor(1.9328, grad_fn=<AddBackward0>)
# loss: tensor(1.9211, grad_fn=<AddBackward0>)
# loss: tensor(1.9096, grad_fn=<AddBackward0>)
# loss: tensor(1.8982, grad_fn=<AddBackward0>)
# loss: tensor(1.8869, grad_fn=<AddBackward0>)
# loss: tensor(1.8757, grad_fn=<AddBackward0>)
# loss: tensor(1.8646, grad_fn=<AddBackward0>)
# loss: tensor(1.8536, grad_fn=<AddBackward0>)
# loss: tensor(1.8427, grad_fn=<AddBackward0>)
# loss: tensor(1.8319, grad_fn=<AddBackward0>)
# loss: tensor(1.8212, grad_fn=<AddBackward0>)
# loss: tensor(1.8106, grad_fn=<AddBackward0>)
# loss: tensor(1.8001, grad_fn=<AddBackward0>)
# loss: tensor(1.7897, grad_fn=<AddBackward0>)
# loss: tensor(1.7794, grad_fn=<AddBackward0>)
# loss: tensor(1.7692, grad_fn=<AddBackward0>)
# loss: tensor(1.7590, grad_fn=<AddBackward0>)
# loss: tensor(1.7490, grad_fn=<AddBackward0>)
# loss: tensor(1.7390, grad_fn=<AddBackward0>)
# loss: tensor(1.7291, grad_fn=<AddBackward0>)
# loss: tensor(1.7193, grad_fn=<AddBackward0>)
# loss: tensor(1.7096, grad_fn=<AddBackward0>)
# loss: tensor(1.7000, grad_fn=<AddBackward0>)
# loss: tensor(1.6905, grad_fn=<AddBackward0>)
# loss: tensor(1.6810, grad_fn=<AddBackward0>)
# loss: tensor(1.6716, grad_fn=<AddBackward0>)
# loss: tensor(1.6623, grad_fn=<AddBackward0>)
# loss: tensor(1.6531, grad_fn=<AddBackward0>)
# loss: tensor(1.6440, grad_fn=<AddBackward0>)
# loss: tensor(1.6349, grad_fn=<AddBackward0>)
# loss: tensor(1.6259, grad_fn=<AddBackward0>)
# loss: tensor(1.6170, grad_fn=<AddBackward0>)
# loss: tensor(1.6082, grad_fn=<AddBackward0>)
# loss: tensor(1.5994, grad_fn=<AddBackward0>)
# loss: tensor(1.5907, grad_fn=<AddBackward0>)
# loss: tensor(1.5821, grad_fn=<AddBackward0>)
# loss: tensor(1.5736, grad_fn=<AddBackward0>)
# loss: tensor(1.5651, grad_fn=<AddBackward0>)
# loss: tensor(1.5567, grad_fn=<AddBackward0>)
# loss: tensor(1.5484, grad_fn=<AddBackward0>)
# loss: tensor(1.5401, grad_fn=<AddBackward0>)
# loss: tensor(1.5319, grad_fn=<AddBackward0>)
# loss: tensor(1.5238, grad_fn=<AddBackward0>)
# loss: tensor(1.5157, grad_fn=<AddBackward0>)
# loss: tensor(1.5077, grad_fn=<AddBackward0>)
# loss: tensor(1.4998, grad_fn=<AddBackward0>)
# loss: tensor(1.4919, grad_fn=<AddBackward0>)
# loss: tensor(1.4841, grad_fn=<AddBackward0>)
# loss: tensor(1.4764, grad_fn=<AddBackward0>)
# loss: tensor(1.4687, grad_fn=<AddBackward0>)
# loss: tensor(1.4611, grad_fn=<AddBackward0>)
# loss: tensor(1.4535, grad_fn=<AddBackward0>)
# loss: tensor(1.4460, grad_fn=<AddBackward0>)
# loss: tensor(1.4386, grad_fn=<AddBackward0>)
# loss: tensor(1.4312, grad_fn=<AddBackward0>)
# loss: tensor(1.4239, grad_fn=<AddBackward0>)
# loss: tensor(1.4167, grad_fn=<AddBackward0>)
# loss: tensor(1.4094, grad_fn=<AddBackward0>)
# loss: tensor(1.4023, grad_fn=<AddBackward0>)
# loss: tensor(1.3952, grad_fn=<AddBackward0>)
# loss: tensor(1.3882, grad_fn=<AddBackward0>)
# loss: tensor(1.3812, grad_fn=<AddBackward0>)
# loss: tensor(1.3743, grad_fn=<AddBackward0>)
# loss: tensor(1.3674, grad_fn=<AddBackward0>)
# loss: tensor(1.3606, grad_fn=<AddBackward0>)
# loss: tensor(1.3538, grad_fn=<AddBackward0>)
# loss: tensor(1.3471, grad_fn=<AddBackward0>)
# loss: tensor(1.3404, grad_fn=<AddBackward0>)
# loss: tensor(1.3338, grad_fn=<AddBackward0>)
# loss: tensor(1.3273, grad_fn=<AddBackward0>)
# loss: tensor(1.3208, grad_fn=<AddBackward0>)
# loss: tensor(1.3143, grad_fn=<AddBackward0>)
# loss: tensor(1.3079, grad_fn=<AddBackward0>)
# loss: tensor(1.3015, grad_fn=<AddBackward0>)
# loss: tensor(1.2952, grad_fn=<AddBackward0>)
# loss: tensor(1.2889, grad_fn=<AddBackward0>)
# loss: tensor(1.2827, grad_fn=<AddBackward0>)
# loss: tensor(1.2765, grad_fn=<AddBackward0>)
# loss: tensor(1.2704, grad_fn=<AddBackward0>)
# loss: tensor(1.2643, grad_fn=<AddBackward0>)
# loss: tensor(1.2583, grad_fn=<AddBackward0>)
# loss: tensor(1.2523, grad_fn=<AddBackward0>)
# loss: tensor(1.2464, grad_fn=<AddBackward0>)
# loss: tensor(1.2405, grad_fn=<AddBackward0>)
# loss: tensor(1.2346, grad_fn=<AddBackward0>)
# loss: tensor(1.2288, grad_fn=<AddBackward0>)
# step=400 - loss=1.2288
# loss: tensor(1.2230, grad_fn=<AddBackward0>)
# loss: tensor(1.2173, grad_fn=<AddBackward0>)
# loss: tensor(1.2116, grad_fn=<AddBackward0>)
# loss: tensor(1.2060, grad_fn=<AddBackward0>)
# loss: tensor(1.2004, grad_fn=<AddBackward0>)
# loss: tensor(1.1948, grad_fn=<AddBackward0>)
# loss: tensor(1.1893, grad_fn=<AddBackward0>)
# loss: tensor(1.1838, grad_fn=<AddBackward0>)
# loss: tensor(1.1784, grad_fn=<AddBackward0>)
# loss: tensor(1.1729, grad_fn=<AddBackward0>)
# loss: tensor(1.1676, grad_fn=<AddBackward0>)
# loss: tensor(1.1623, grad_fn=<AddBackward0>)
# loss: tensor(1.1570, grad_fn=<AddBackward0>)
# loss: tensor(1.1517, grad_fn=<AddBackward0>)
# loss: tensor(1.1465, grad_fn=<AddBackward0>)
# loss: tensor(1.1413, grad_fn=<AddBackward0>)
# loss: tensor(1.1362, grad_fn=<AddBackward0>)
# loss: tensor(1.1311, grad_fn=<AddBackward0>)
# loss: tensor(1.1260, grad_fn=<AddBackward0>)
# loss: tensor(1.1210, grad_fn=<AddBackward0>)
# loss: tensor(1.1160, grad_fn=<AddBackward0>)
# loss: tensor(1.1111, grad_fn=<AddBackward0>)
# loss: tensor(1.1061, grad_fn=<AddBackward0>)
# loss: tensor(1.1012, grad_fn=<AddBackward0>)
# loss: tensor(1.0964, grad_fn=<AddBackward0>)
# loss: tensor(1.0916, grad_fn=<AddBackward0>)
# loss: tensor(1.0868, grad_fn=<AddBackward0>)
# loss: tensor(1.0820, grad_fn=<AddBackward0>)
# loss: tensor(1.0773, grad_fn=<AddBackward0>)
# loss: tensor(1.0726, grad_fn=<AddBackward0>)
# loss: tensor(1.0680, grad_fn=<AddBackward0>)
# loss: tensor(1.0633, grad_fn=<AddBackward0>)
# loss: tensor(1.0588, grad_fn=<AddBackward0>)
# loss: tensor(1.0542, grad_fn=<AddBackward0>)
# loss: tensor(1.0497, grad_fn=<AddBackward0>)
# loss: tensor(1.0452, grad_fn=<AddBackward0>)
# loss: tensor(1.0407, grad_fn=<AddBackward0>)
# loss: tensor(1.0363, grad_fn=<AddBackward0>)
# loss: tensor(1.0319, grad_fn=<AddBackward0>)
# loss: tensor(1.0275, grad_fn=<AddBackward0>)
# loss: tensor(1.0232, grad_fn=<AddBackward0>)
# loss: tensor(1.0188, grad_fn=<AddBackward0>)
# loss: tensor(1.0146, grad_fn=<AddBackward0>)
# loss: tensor(1.0103, grad_fn=<AddBackward0>)
# loss: tensor(1.0061, grad_fn=<AddBackward0>)
# loss: tensor(1.0019, grad_fn=<AddBackward0>)
# loss: tensor(0.9977, grad_fn=<AddBackward0>)
# loss: tensor(0.9936, grad_fn=<AddBackward0>)
# loss: tensor(0.9894, grad_fn=<AddBackward0>)
# loss: tensor(0.9854, grad_fn=<AddBackward0>)
# loss: tensor(0.9813, grad_fn=<AddBackward0>)
# loss: tensor(0.9773, grad_fn=<AddBackward0>)
# loss: tensor(0.9733, grad_fn=<AddBackward0>)
# loss: tensor(0.9693, grad_fn=<AddBackward0>)
# loss: tensor(0.9653, grad_fn=<AddBackward0>)
# loss: tensor(0.9614, grad_fn=<AddBackward0>)
# loss: tensor(0.9575, grad_fn=<AddBackward0>)
# loss: tensor(0.9536, grad_fn=<AddBackward0>)
# loss: tensor(0.9498, grad_fn=<AddBackward0>)
# loss: tensor(0.9459, grad_fn=<AddBackward0>)
# loss: tensor(0.9421, grad_fn=<AddBackward0>)
# loss: tensor(0.9384, grad_fn=<AddBackward0>)
# loss: tensor(0.9346, grad_fn=<AddBackward0>)
# loss: tensor(0.9309, grad_fn=<AddBackward0>)
# loss: tensor(0.9272, grad_fn=<AddBackward0>)
# loss: tensor(0.9235, grad_fn=<AddBackward0>)
# loss: tensor(0.9199, grad_fn=<AddBackward0>)
# loss: tensor(0.9162, grad_fn=<AddBackward0>)
# loss: tensor(0.9126, grad_fn=<AddBackward0>)
# loss: tensor(0.9091, grad_fn=<AddBackward0>)
# loss: tensor(0.9055, grad_fn=<AddBackward0>)
# loss: tensor(0.9020, grad_fn=<AddBackward0>)
# loss: tensor(0.8984, grad_fn=<AddBackward0>)
# loss: tensor(0.8950, grad_fn=<AddBackward0>)
# loss: tensor(0.8915, grad_fn=<AddBackward0>)
# loss: tensor(0.8880, grad_fn=<AddBackward0>)
# loss: tensor(0.8846, grad_fn=<AddBackward0>)
# loss: tensor(0.8812, grad_fn=<AddBackward0>)
# loss: tensor(0.8778, grad_fn=<AddBackward0>)
# loss: tensor(0.8745, grad_fn=<AddBackward0>)
# loss: tensor(0.8711, grad_fn=<AddBackward0>)
# loss: tensor(0.8678, grad_fn=<AddBackward0>)
# loss: tensor(0.8645, grad_fn=<AddBackward0>)
# loss: tensor(0.8613, grad_fn=<AddBackward0>)
# loss: tensor(0.8580, grad_fn=<AddBackward0>)
# loss: tensor(0.8548, grad_fn=<AddBackward0>)
# loss: tensor(0.8516, grad_fn=<AddBackward0>)
# loss: tensor(0.8484, grad_fn=<AddBackward0>)
# loss: tensor(0.8452, grad_fn=<AddBackward0>)
# loss: tensor(0.8420, grad_fn=<AddBackward0>)
# loss: tensor(0.8389, grad_fn=<AddBackward0>)
# loss: tensor(0.8358, grad_fn=<AddBackward0>)
# loss: tensor(0.8327, grad_fn=<AddBackward0>)
# loss: tensor(0.8296, grad_fn=<AddBackward0>)
# loss: tensor(0.8266, grad_fn=<AddBackward0>)
# loss: tensor(0.8235, grad_fn=<AddBackward0>)
# loss: tensor(0.8205, grad_fn=<AddBackward0>)
# loss: tensor(0.8175, grad_fn=<AddBackward0>)
# loss: tensor(0.8145, grad_fn=<AddBackward0>)
# loss: tensor(0.8116, grad_fn=<AddBackward0>)
# step=500 - loss=0.8116
# loss: tensor(0.8086, grad_fn=<AddBackward0>)
# loss: tensor(0.8057, grad_fn=<AddBackward0>)
# loss: tensor(0.8028, grad_fn=<AddBackward0>)
# loss: tensor(0.7999, grad_fn=<AddBackward0>)
# loss: tensor(0.7970, grad_fn=<AddBackward0>)
# loss: tensor(0.7942, grad_fn=<AddBackward0>)
# loss: tensor(0.7913, grad_fn=<AddBackward0>)
# loss: tensor(0.7885, grad_fn=<AddBackward0>)
# loss: tensor(0.7857, grad_fn=<AddBackward0>)
# loss: tensor(0.7829, grad_fn=<AddBackward0>)
# loss: tensor(0.7801, grad_fn=<AddBackward0>)
# loss: tensor(0.7774, grad_fn=<AddBackward0>)
# loss: tensor(0.7746, grad_fn=<AddBackward0>)
# loss: tensor(0.7719, grad_fn=<AddBackward0>)
# loss: tensor(0.7692, grad_fn=<AddBackward0>)
# loss: tensor(0.7665, grad_fn=<AddBackward0>)
# loss: tensor(0.7639, grad_fn=<AddBackward0>)
# loss: tensor(0.7612, grad_fn=<AddBackward0>)
# loss: tensor(0.7586, grad_fn=<AddBackward0>)
# loss: tensor(0.7559, grad_fn=<AddBackward0>)
# loss: tensor(0.7533, grad_fn=<AddBackward0>)
# loss: tensor(0.7507, grad_fn=<AddBackward0>)
# loss: tensor(0.7482, grad_fn=<AddBackward0>)
# loss: tensor(0.7456, grad_fn=<AddBackward0>)
# loss: tensor(0.7430, grad_fn=<AddBackward0>)
# loss: tensor(0.7405, grad_fn=<AddBackward0>)
# loss: tensor(0.7380, grad_fn=<AddBackward0>)
# loss: tensor(0.7355, grad_fn=<AddBackward0>)
# loss: tensor(0.7330, grad_fn=<AddBackward0>)
# loss: tensor(0.7305, grad_fn=<AddBackward0>)
# loss: tensor(0.7281, grad_fn=<AddBackward0>)
# loss: tensor(0.7256, grad_fn=<AddBackward0>)
# loss: tensor(0.7232, grad_fn=<AddBackward0>)
# loss: tensor(0.7208, grad_fn=<AddBackward0>)
# loss: tensor(0.7184, grad_fn=<AddBackward0>)
# loss: tensor(0.7160, grad_fn=<AddBackward0>)
# loss: tensor(0.7136, grad_fn=<AddBackward0>)
# loss: tensor(0.7112, grad_fn=<AddBackward0>)
# loss: tensor(0.7089, grad_fn=<AddBackward0>)
# ...
# loss: tensor(0.5193, grad_fn=<AddBackward0>)
# loss: tensor(0.5180, grad_fn=<AddBackward0>)
# loss: tensor(0.5166, grad_fn=<AddBackward0>)
# loss: tensor(0.5153, grad_fn=<AddBackward0>)
# loss: tensor(0.5140, grad_fn=<AddBackward0>)
# loss: tensor(0.5127, grad_fn=<AddBackward0>)
# loss: tensor(0.5114, grad_fn=<AddBackward0>)
# loss: tensor(0.5101, grad_fn=<AddBackward0>)
# loss: tensor(0.5089, grad_fn=<AddBackward0>)
# loss: tensor(0.5076, grad_fn=<AddBackward0>)
# loss: tensor(0.5063, grad_fn=<AddBackward0>)
# loss: tensor(0.5051, grad_fn=<AddBackward0>)
# loss: tensor(0.5038, grad_fn=<AddBackward0>)
# loss: tensor(0.5025, grad_fn=<AddBackward0>)
# loss: tensor(0.5013, grad_fn=<AddBackward0>)
# loss: tensor(0.5001, grad_fn=<AddBackward0>)
# loss: tensor(0.4988, grad_fn=<AddBackward0>)
# loss: tensor(0.4976, grad_fn=<AddBackward0>)
# loss: tensor(0.4964, grad_fn=<AddBackward0>)
# loss: tensor(0.4952, grad_fn=<AddBackward0>)
# loss: tensor(0.4940, grad_fn=<AddBackward0>)
# loss: tensor(0.4927, grad_fn=<AddBackward0>)
# loss: tensor(0.4915, grad_fn=<AddBackward0>)
# loss: tensor(0.4904, grad_fn=<AddBackward0>)
# loss: tensor(0.4892, grad_fn=<AddBackward0>)
# loss: tensor(0.4880, grad_fn=<AddBackward0>)
# loss: tensor(0.4868, grad_fn=<AddBackward0>)
# loss: tensor(0.4856, grad_fn=<AddBackward0>)
# loss: tensor(0.4845, grad_fn=<AddBackward0>)
# loss: tensor(0.4833, grad_fn=<AddBackward0>)
# loss: tensor(0.4822, grad_fn=<AddBackward0>)
# loss: tensor(0.4810, grad_fn=<AddBackward0>)
# loss: tensor(0.4799, grad_fn=<AddBackward0>)
# loss: tensor(0.4787, grad_fn=<AddBackward0>)
# loss: tensor(0.4776, grad_fn=<AddBackward0>)
# loss: tensor(0.4765, grad_fn=<AddBackward0>)
# loss: tensor(0.4753, grad_fn=<AddBackward0>)
# loss: tensor(0.4742, grad_fn=<AddBackward0>)
# loss: tensor(0.4731, grad_fn=<AddBackward0>)
# loss: tensor(0.4720, grad_fn=<AddBackward0>)
# loss: tensor(0.4709, grad_fn=<AddBackward0>)
# loss: tensor(0.4698, grad_fn=<AddBackward0>)
# loss: tensor(0.4687, grad_fn=<AddBackward0>)
# loss: tensor(0.4676, grad_fn=<AddBackward0>)
# loss: tensor(0.4665, grad_fn=<AddBackward0>)
# loss: tensor(0.4654, grad_fn=<AddBackward0>)
# loss: tensor(0.4644, grad_fn=<AddBackward0>)
# loss: tensor(0.4633, grad_fn=<AddBackward0>)
# loss: tensor(0.4622, grad_fn=<AddBackward0>)
# loss: tensor(0.4612, grad_fn=<AddBackward0>)
# loss: tensor(0.4601, grad_fn=<AddBackward0>)
# loss: tensor(0.4591, grad_fn=<AddBackward0>)
# loss: tensor(0.4580, grad_fn=<AddBackward0>)
# loss: tensor(0.4570, grad_fn=<AddBackward0>)
# loss: tensor(0.4559, grad_fn=<AddBackward0>)
# step=700 - loss=0.4559
# loss: tensor(0.4549, grad_fn=<AddBackward0>)
# loss: tensor(0.4539, grad_fn=<AddBackward0>)
# loss: tensor(0.4529, grad_fn=<AddBackward0>)
# loss: tensor(0.4518, grad_fn=<AddBackward0>)
# loss: tensor(0.4508, grad_fn=<AddBackward0>)
# loss: tensor(0.4498, grad_fn=<AddBackward0>)
# loss: tensor(0.4488, grad_fn=<AddBackward0>)
# loss: tensor(0.4478, grad_fn=<AddBackward0>)
# loss: tensor(0.4468, grad_fn=<AddBackward0>)
# loss: tensor(0.4458, grad_fn=<AddBackward0>)
# loss: tensor(0.4448, grad_fn=<AddBackward0>)
# loss: tensor(0.4438, grad_fn=<AddBackward0>)
# loss: tensor(0.4429, grad_fn=<AddBackward0>)
# loss: tensor(0.4419, grad_fn=<AddBackward0>)
# loss: tensor(0.4409, grad_fn=<AddBackward0>)
# loss: tensor(0.4400, grad_fn=<AddBackward0>)
# loss: tensor(0.4390, grad_fn=<AddBackward0>)
# loss: tensor(0.4380, grad_fn=<AddBackward0>)
# loss: tensor(0.4371, grad_fn=<AddBackward0>)
# loss: tensor(0.4361, grad_fn=<AddBackward0>)
# loss: tensor(0.4352, grad_fn=<AddBackward0>)
# loss: tensor(0.4342, grad_fn=<AddBackward0>)
# loss: tensor(0.4333, grad_fn=<AddBackward0>)
# loss: tensor(0.4324, grad_fn=<AddBackward0>)
# loss: tensor(0.4314, grad_fn=<AddBackward0>)
# loss: tensor(0.4305, grad_fn=<AddBackward0>)
# loss: tensor(0.4296, grad_fn=<AddBackward0>)
# loss: tensor(0.4287, grad_fn=<AddBackward0>)
# loss: tensor(0.4277, grad_fn=<AddBackward0>)
# loss: tensor(0.4268, grad_fn=<AddBackward0>)
# loss: tensor(0.4259, grad_fn=<AddBackward0>)
# loss: tensor(0.4250, grad_fn=<AddBackward0>)
# loss: tensor(0.4241, grad_fn=<AddBackward0>)
# loss: tensor(0.4232, grad_fn=<AddBackward0>)
# loss: tensor(0.4223, grad_fn=<AddBackward0>)
# loss: tensor(0.4214, grad_fn=<AddBackward0>)
# loss: tensor(0.4206, grad_fn=<AddBackward0>)
# loss: tensor(0.4197, grad_fn=<AddBackward0>)
# loss: tensor(0.4188, grad_fn=<AddBackward0>)
# loss: tensor(0.4179, grad_fn=<AddBackward0>)
# loss: tensor(0.4170, grad_fn=<AddBackward0>)
# loss: tensor(0.4162, grad_fn=<AddBackward0>)
# loss: tensor(0.4153, grad_fn=<AddBackward0>)
# loss: tensor(0.4145, grad_fn=<AddBackward0>)
# loss: tensor(0.4136, grad_fn=<AddBackward0>)
# loss: tensor(0.4127, grad_fn=<AddBackward0>)
# loss: tensor(0.4119, grad_fn=<AddBackward0>)
# loss: tensor(0.4110, grad_fn=<AddBackward0>)
# loss: tensor(0.4102, grad_fn=<AddBackward0>)
# loss: tensor(0.4094, grad_fn=<AddBackward0>)
# loss: tensor(0.4085, grad_fn=<AddBackward0>)
# loss: tensor(0.4077, grad_fn=<AddBackward0>)
# loss: tensor(0.4069, grad_fn=<AddBackward0>)
# loss: tensor(0.4060, grad_fn=<AddBackward0>)
# loss: tensor(0.4052, grad_fn=<AddBackward0>)
# loss: tensor(0.4044, grad_fn=<AddBackward0>)
# loss: tensor(0.4036, grad_fn=<AddBackward0>)
# loss: tensor(0.4028, grad_fn=<AddBackward0>)
# loss: tensor(0.4019, grad_fn=<AddBackward0>)
# loss: tensor(0.4011, grad_fn=<AddBackward0>)
# loss: tensor(0.4003, grad_fn=<AddBackward0>)
# loss: tensor(0.3995, grad_fn=<AddBackward0>)
# loss: tensor(0.3987, grad_fn=<AddBackward0>)
# loss: tensor(0.3979, grad_fn=<AddBackward0>)
# loss: tensor(0.3971, grad_fn=<AddBackward0>)
# loss: tensor(0.3963, grad_fn=<AddBackward0>)
# loss: tensor(0.3956, grad_fn=<AddBackward0>)
# loss: tensor(0.3948, grad_fn=<AddBackward0>)
# loss: tensor(0.3940, grad_fn=<AddBackward0>)
# loss: tensor(0.3932, grad_fn=<AddBackward0>)
# loss: tensor(0.3924, grad_fn=<AddBackward0>)
# loss: tensor(0.3917, grad_fn=<AddBackward0>)
# loss: tensor(0.3909, grad_fn=<AddBackward0>)
# loss: tensor(0.3901, grad_fn=<AddBackward0>)
# loss: tensor(0.3894, grad_fn=<AddBackward0>)
# loss: tensor(0.3886, grad_fn=<AddBackward0>)
# loss: tensor(0.3879, grad_fn=<AddBackward0>)
# loss: tensor(0.3871, grad_fn=<AddBackward0>)
# loss: tensor(0.3864, grad_fn=<AddBackward0>)
# loss: tensor(0.3856, grad_fn=<AddBackward0>)
# loss: tensor(0.3849, grad_fn=<AddBackward0>)
# loss: tensor(0.3841, grad_fn=<AddBackward0>)
# loss: tensor(0.3834, grad_fn=<AddBackward0>)
# loss: tensor(0.3826, grad_fn=<AddBackward0>)
# loss: tensor(0.3819, grad_fn=<AddBackward0>)
# loss: tensor(0.3812, grad_fn=<AddBackward0>)
# loss: tensor(0.3804, grad_fn=<AddBackward0>)
# loss: tensor(0.3797, grad_fn=<AddBackward0>)
# loss: tensor(0.3790, grad_fn=<AddBackward0>)
# loss: tensor(0.3783, grad_fn=<AddBackward0>)
# loss: tensor(0.3776, grad_fn=<AddBackward0>)
# loss: tensor(0.3768, grad_fn=<AddBackward0>)
# loss: tensor(0.3761, grad_fn=<AddBackward0>)
# loss: tensor(0.3754, grad_fn=<AddBackward0>)
# loss: tensor(0.3747, grad_fn=<AddBackward0>)
# loss: tensor(0.3740, grad_fn=<AddBackward0>)
# loss: tensor(0.3733, grad_fn=<AddBackward0>)
# loss: tensor(0.3726, grad_fn=<AddBackward0>)
# loss: tensor(0.3719, grad_fn=<AddBackward0>)
# loss: tensor(0.3712, grad_fn=<AddBackward0>)
# step=800 - loss=0.3712
# loss: tensor(0.3705, grad_fn=<AddBackward0>)
# loss: tensor(0.3698, grad_fn=<AddBackward0>)
# loss: tensor(0.3691, grad_fn=<AddBackward0>)
# loss: tensor(0.3684, grad_fn=<AddBackward0>)
# loss: tensor(0.3678, grad_fn=<AddBackward0>)
# loss: tensor(0.3671, grad_fn=<AddBackward0>)
# loss: tensor(0.3664, grad_fn=<AddBackward0>)
# loss: tensor(0.3657, grad_fn=<AddBackward0>)
# loss: tensor(0.3651, grad_fn=<AddBackward0>)
# loss: tensor(0.3644, grad_fn=<AddBackward0>)
# loss: tensor(0.3637, grad_fn=<AddBackward0>)
# loss: tensor(0.3630, grad_fn=<AddBackward0>)
# loss: tensor(0.3624, grad_fn=<AddBackward0>)
# loss: tensor(0.3617, grad_fn=<AddBackward0>)
# loss: tensor(0.3611, grad_fn=<AddBackward0>)
# loss: tensor(0.3604, grad_fn=<AddBackward0>)
# loss: tensor(0.3597, grad_fn=<AddBackward0>)
# loss: tensor(0.3591, grad_fn=<AddBackward0>)
# loss: tensor(0.3584, grad_fn=<AddBackward0>)
# loss: tensor(0.3578, grad_fn=<AddBackward0>)
# loss: tensor(0.3571, grad_fn=<AddBackward0>)
# loss: tensor(0.3565, grad_fn=<AddBackward0>)
# loss: tensor(0.3559, grad_fn=<AddBackward0>)
# loss: tensor(0.3552, grad_fn=<AddBackward0>)
# loss: tensor(0.3546, grad_fn=<AddBackward0>)
# loss: tensor(0.3539, grad_fn=<AddBackward0>)
# loss: tensor(0.3533, grad_fn=<AddBackward0>)
# loss: tensor(0.3527, grad_fn=<AddBackward0>)
# loss: tensor(0.3520, grad_fn=<AddBackward0>)
# loss: tensor(0.3514, grad_fn=<AddBackward0>)
# loss: tensor(0.3508, grad_fn=<AddBackward0>)
# loss: tensor(0.3502, grad_fn=<AddBackward0>)
# loss: tensor(0.3496, grad_fn=<AddBackward0>)
# loss: tensor(0.3489, grad_fn=<AddBackward0>)
# loss: tensor(0.3483, grad_fn=<AddBackward0>)
# loss: tensor(0.3477, grad_fn=<AddBackward0>)
# loss: tensor(0.3471, grad_fn=<AddBackward0>)
# loss: tensor(0.3465, grad_fn=<AddBackward0>)
# loss: tensor(0.3459, grad_fn=<AddBackward0>)
# loss: tensor(0.3453, grad_fn=<AddBackward0>)
# loss: tensor(0.3447, grad_fn=<AddBackward0>)
# loss: tensor(0.3440, grad_fn=<AddBackward0>)
# loss: tensor(0.3434, grad_fn=<AddBackward0>)
# loss: tensor(0.3428, grad_fn=<AddBackward0>)
# loss: tensor(0.3422, grad_fn=<AddBackward0>)
# loss: tensor(0.3417, grad_fn=<AddBackward0>)
# loss: tensor(0.3411, grad_fn=<AddBackward0>)
# loss: tensor(0.3405, grad_fn=<AddBackward0>)
# loss: tensor(0.3399, grad_fn=<AddBackward0>)
# loss: tensor(0.3393, grad_fn=<AddBackward0>)
# loss: tensor(0.3387, grad_fn=<AddBackward0>)
# loss: tensor(0.3381, grad_fn=<AddBackward0>)
# loss: tensor(0.3375, grad_fn=<AddBackward0>)
# loss: tensor(0.3369, grad_fn=<AddBackward0>)
# loss: tensor(0.3364, grad_fn=<AddBackward0>)
# loss: tensor(0.3358, grad_fn=<AddBackward0>)
# loss: tensor(0.3352, grad_fn=<AddBackward0>)
# loss: tensor(0.3346, grad_fn=<AddBackward0>)
# loss: tensor(0.3341, grad_fn=<AddBackward0>)
# loss: tensor(0.3335, grad_fn=<AddBackward0>)
# loss: tensor(0.3329, grad_fn=<AddBackward0>)
# loss: tensor(0.3324, grad_fn=<AddBackward0>)
# loss: tensor(0.3318, grad_fn=<AddBackward0>)
# loss: tensor(0.3312, grad_fn=<AddBackward0>)
# loss: tensor(0.3307, grad_fn=<AddBackward0>)
# loss: tensor(0.3301, grad_fn=<AddBackward0>)
# loss: tensor(0.3295, grad_fn=<AddBackward0>)
# loss: tensor(0.3290, grad_fn=<AddBackward0>)
# loss: tensor(0.3284, grad_fn=<AddBackward0>)
# loss: tensor(0.3279, grad_fn=<AddBackward0>)
# loss: tensor(0.3273, grad_fn=<AddBackward0>)
# loss: tensor(0.3268, grad_fn=<AddBackward0>)
# loss: tensor(0.3262, grad_fn=<AddBackward0>)
# loss: tensor(0.3257, grad_fn=<AddBackward0>)
# loss: tensor(0.3251, grad_fn=<AddBackward0>)
# loss: tensor(0.3246, grad_fn=<AddBackward0>)
# loss: tensor(0.3240, grad_fn=<AddBackward0>)
# loss: tensor(0.3235, grad_fn=<AddBackward0>)
# loss: tensor(0.3230, grad_fn=<AddBackward0>)
# loss: tensor(0.3224, grad_fn=<AddBackward0>)
# loss: tensor(0.3219, grad_fn=<AddBackward0>)
# loss: tensor(0.3213, grad_fn=<AddBackward0>)
# loss: tensor(0.3208, grad_fn=<AddBackward0>)
# loss: tensor(0.3203, grad_fn=<AddBackward0>)
# loss: tensor(0.3198, grad_fn=<AddBackward0>)
# loss: tensor(0.3192, grad_fn=<AddBackward0>)
# loss: tensor(0.3187, grad_fn=<AddBackward0>)
# loss: tensor(0.3182, grad_fn=<AddBackward0>)
# loss: tensor(0.3176, grad_fn=<AddBackward0>)
# loss: tensor(0.3171, grad_fn=<AddBackward0>)
# loss: tensor(0.3166, grad_fn=<AddBackward0>)
# loss: tensor(0.3161, grad_fn=<AddBackward0>)
# loss: tensor(0.3156, grad_fn=<AddBackward0>)
# loss: tensor(0.3150, grad_fn=<AddBackward0>)
# loss: tensor(0.3145, grad_fn=<AddBackward0>)
# loss: tensor(0.3140, grad_fn=<AddBackward0>)
# loss: tensor(0.3135, grad_fn=<AddBackward0>)
# loss: tensor(0.3130, grad_fn=<AddBackward0>)
# loss: tensor(0.3125, grad_fn=<AddBackward0>)
# loss: tensor(0.3120, grad_fn=<AddBackward0>)
# step=900 - loss=0.3120
# loss: tensor(0.3114, grad_fn=<AddBackward0>)
# loss: tensor(0.3109, grad_fn=<AddBackward0>)
# loss: tensor(0.3104, grad_fn=<AddBackward0>)
# loss: tensor(0.3099, grad_fn=<AddBackward0>)
# loss: tensor(0.3094, grad_fn=<AddBackward0>)
# loss: tensor(0.3089, grad_fn=<AddBackward0>)
# loss: tensor(0.3084, grad_fn=<AddBackward0>)
# loss: tensor(0.3079, grad_fn=<AddBackward0>)
# loss: tensor(0.3074, grad_fn=<AddBackward0>)
# loss: tensor(0.3069, grad_fn=<AddBackward0>)
# loss: tensor(0.3064, grad_fn=<AddBackward0>)
# loss: tensor(0.3059, grad_fn=<AddBackward0>)
# loss: tensor(0.3054, grad_fn=<AddBackward0>)
# loss: tensor(0.3049, grad_fn=<AddBackward0>)
# loss: tensor(0.3045, grad_fn=<AddBackward0>)
# loss: tensor(0.3040, grad_fn=<AddBackward0>)
# loss: tensor(0.3035, grad_fn=<AddBackward0>)
# loss: tensor(0.3030, grad_fn=<AddBackward0>)
# loss: tensor(0.3025, grad_fn=<AddBackward0>)
# loss: tensor(0.3020, grad_fn=<AddBackward0>)
# loss: tensor(0.3015, grad_fn=<AddBackward0>)
# loss: tensor(0.3010, grad_fn=<AddBackward0>)
# loss: tensor(0.3006, grad_fn=<AddBackward0>)
# loss: tensor(0.3001, grad_fn=<AddBackward0>)
# loss: tensor(0.2996, grad_fn=<AddBackward0>)
# loss: tensor(0.2991, grad_fn=<AddBackward0>)
# loss: tensor(0.2986, grad_fn=<AddBackward0>)
# loss: tensor(0.2982, grad_fn=<AddBackward0>)
# loss: tensor(0.2977, grad_fn=<AddBackward0>)
# loss: tensor(0.2972, grad_fn=<AddBackward0>)
# loss: tensor(0.2967, grad_fn=<AddBackward0>)
# loss: tensor(0.2963, grad_fn=<AddBackward0>)
# loss: tensor(0.2958, grad_fn=<AddBackward0>)
# loss: tensor(0.2953, grad_fn=<AddBackward0>)
# loss: tensor(0.2949, grad_fn=<AddBackward0>)
# loss: tensor(0.2944, grad_fn=<AddBackward0>)
# loss: tensor(0.2939, grad_fn=<AddBackward0>)
# loss: tensor(0.2935, grad_fn=<AddBackward0>)
# loss: tensor(0.2930, grad_fn=<AddBackward0>)
# loss: tensor(0.2925, grad_fn=<AddBackward0>)
# loss: tensor(0.2921, grad_fn=<AddBackward0>)
# loss: tensor(0.2916, grad_fn=<AddBackward0>)
# loss: tensor(0.2912, grad_fn=<AddBackward0>)
# loss: tensor(0.2907, grad_fn=<AddBackward0>)
# loss: tensor(0.2902, grad_fn=<AddBackward0>)
# loss: tensor(0.2898, grad_fn=<AddBackward0>)
# loss: tensor(0.2893, grad_fn=<AddBackward0>)
# loss: tensor(0.2889, grad_fn=<AddBackward0>)
# loss: tensor(0.2884, grad_fn=<AddBackward0>)
# loss: tensor(0.2880, grad_fn=<AddBackward0>)
# loss: tensor(0.2875, grad_fn=<AddBackward0>)
# loss: tensor(0.2871, grad_fn=<AddBackward0>)
# loss: tensor(0.2866, grad_fn=<AddBackward0>)
# loss: tensor(0.2862, grad_fn=<AddBackward0>)
# loss: tensor(0.2857, grad_fn=<AddBackward0>)
# loss: tensor(0.2853, grad_fn=<AddBackward0>)
# loss: tensor(0.2848, grad_fn=<AddBackward0>)
# loss: tensor(0.2844, grad_fn=<AddBackward0>)
# loss: tensor(0.2839, grad_fn=<AddBackward0>)
# loss: tensor(0.2835, grad_fn=<AddBackward0>)
# loss: tensor(0.2830, grad_fn=<AddBackward0>)
# loss: tensor(0.2826, grad_fn=<AddBackward0>)
# loss: tensor(0.2821, grad_fn=<AddBackward0>)
# loss: tensor(0.2817, grad_fn=<AddBackward0>)
# loss: tensor(0.2813, grad_fn=<AddBackward0>)
# loss: tensor(0.2808, grad_fn=<AddBackward0>)
# loss: tensor(0.2804, grad_fn=<AddBackward0>)
# loss: tensor(0.2800, grad_fn=<AddBackward0>)
# loss: tensor(0.2795, grad_fn=<AddBackward0>)
# loss: tensor(0.2791, grad_fn=<AddBackward0>)
# loss: tensor(0.2786, grad_fn=<AddBackward0>)
# loss: tensor(0.2782, grad_fn=<AddBackward0>)
# loss: tensor(0.2778, grad_fn=<AddBackward0>)
# loss: tensor(0.2773, grad_fn=<AddBackward0>)
# loss: tensor(0.2769, grad_fn=<AddBackward0>)
# loss: tensor(0.2765, grad_fn=<AddBackward0>)
# loss: tensor(0.2761, grad_fn=<AddBackward0>)
# loss: tensor(0.2756, grad_fn=<AddBackward0>)
# loss: tensor(0.2752, grad_fn=<AddBackward0>)
# loss: tensor(0.2748, grad_fn=<AddBackward0>)
# loss: tensor(0.2743, grad_fn=<AddBackward0>)
# loss: tensor(0.2739, grad_fn=<AddBackward0>)
# loss: tensor(0.2735, grad_fn=<AddBackward0>)
# loss: tensor(0.2731, grad_fn=<AddBackward0>)
# loss: tensor(0.2726, grad_fn=<AddBackward0>)
# loss: tensor(0.2722, grad_fn=<AddBackward0>)
# loss: tensor(0.2718, grad_fn=<AddBackward0>)
# loss: tensor(0.2714, grad_fn=<AddBackward0>)
# loss: tensor(0.2710, grad_fn=<AddBackward0>)
# loss: tensor(0.2705, grad_fn=<AddBackward0>)
# loss: tensor(0.2701, grad_fn=<AddBackward0>)
# loss: tensor(0.2697, grad_fn=<AddBackward0>)
# loss: tensor(0.2693, grad_fn=<AddBackward0>)
# loss: tensor(0.2689, grad_fn=<AddBackward0>)
# loss: tensor(0.2685, grad_fn=<AddBackward0>)
# loss: tensor(0.2680, grad_fn=<AddBackward0>)
# loss: tensor(0.2676, grad_fn=<AddBackward0>)
# loss: tensor(0.2672, grad_fn=<AddBackward0>)
# loss: tensor(0.2668, grad_fn=<AddBackward0>)

# %%
# get the sources powers estimated with the first approximation model
powers_init_pred = power_parameters[3]
# get the predicted power
#powers_init_pred = torch.sqrt(torch.sum(sources_init_pred**2, dim=1))
powers_init_pred = powers_init_pred/torch.max(powers_init_pred)

# get the sources signals estimated with the real model
sources_pred = parameters[3]
powers_pred = torch.sqrt(torch.sum(sources_pred**2, dim=1))
powers_pred = powers_pred/torch.max(powers_pred)

# get the power of the real sources
powers_true = torch.sqrt(torch.sum(sources_true**2, axis=1))
powers_true = powers_true/torch.max(powers_true)

# %%
plt.figure(figsize=(20, 10))

# Plot parameters during source power reconstruction
plt.subplot(221)
plt.plot(Gammas_power)
plt.title("Gammas")
plt.subplot(222)
plt.title("Sources and Channels during source power reconstruction")
plt.xlabel("x")
plt.ylabel("y")

plt.scatter(positions_power[::5,:,0], positions_power[::5,:,1], c='blue', label="source successive estimated positions")

with torch.no_grad():
    power_pos = power_parameters[2]
    plt.scatter(power_pos[:,0],power_pos[:,1],c='black',s = 100*powers_init_pred, label="source final estimated position")
    channels_pos = X
    plt.scatter(channels_pos[:,0],channels_pos[:,1],c='green', label="channels")
    init_pos = exact_parameters[2]
    plt.scatter(init_pos[:,0],init_pos[:,1],c='red',s=100*powers_true, alpha =0.5, label = "real source positions")
plt.legend()

# plot parameters evolution after initialization
plt.subplot(223)
plt.plot(Gammas)
plt.title("Gammas")
plt.xlabel("steps")
plt.subplot(224)
plt.title("Sources and Channels during source reconstruction")
plt.xlabel("x")
plt.ylabel("y")

plt.scatter(positions[::5,:,0], positions[::5,:,1], c='blue', label="source successive estimated positions")

with torch.no_grad():
    pos = parameters[2]
    plt.scatter(pos[:,0],pos[:,1],c='black',s = 100*powers_pred, label="source final estimated position")
    channels_pos = X
    plt.scatter(channels_pos[:,0],channels_pos[:,1],c='green', label="channels")
    init_pos = exact_parameters[2]
    plt.scatter(init_pos[:,0],init_pos[:,1],c='red',s=100*powers_true, alpha =0.5, label = "real source positions")
plt.legend()

# %%
plt.figure(figsize=(15,8))
with torch.no_grad():
    plt.subplot(221)
    # plot the prediction of signal at the position of the first channel using the model (blue)
    # against the real signal measured at this channel
    plt.plot(predict(torch.tensor(channels_pos[0]), parameters),'b')
    plt.plot(Channels[0],'r')
    plt.title("First channel's location")
    plt.xlabel("time")
    plt.ylabel("signal")
    plt.subplot(222)
    plt.plot(predict(torch.tensor(channels_pos[1]), parameters),'b')
    plt.plot(Channels[1],'r')
    plt.subplot(223)
    # plot the prediction of signal using the model against the prediction with the exact parameters
    plt.plot(predict(torch.tensor([1.,1.]), parameters),'b')
    plt.plot(predict(torch.tensor([1.,1.]), exact_parameters),'r')
    plt.subplot(224)
    plt.plot(predict(torch.tensor([0.,0.]), parameters),'b')
    plt.plot(predict(torch.tensor([0.,0.]), exact_parameters),'r')

    plt.suptitle("Comparison of real signals against estimated signals at different locations");
# Out:
# <ipython-input-38-90b7cc8e1038>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(predict(torch.tensor(channels_pos[0]), parameters),'b')
# <ipython-input-38-90b7cc8e1038>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(predict(torch.tensor(channels_pos[1]), parameters),'b')

# %%
estim_pos = parameters[2]
estimated_sources = parameters[3]
exact_pos = exact_parameters[2]
exact_sources = exact_parameters[3]

# %%
inter_source_dist = torch.cdist(estim_pos, exact_pos, p=2.0)
assigned_sources = torch.argmin(inter_source_dist, dim=1)
print(inter_source_dist)
print(assigned_sources)

covered_sources = torch.unique(assigned_sources, sorted=False)
print(covered_sources)
# Out:
# tensor([[0.4058, 0.0226, 0.7705, 0.8254, 0.1135, 1.0984, 0.3402, 0.3328],
#         [0.6852, 1.0879, 0.5385, 0.7419, 1.0328, 0.0201, 0.7443, 0.7999],
#         [0.4237, 0.0069, 0.7693, 0.8164, 0.1429, 1.1108, 0.3573, 0.3566],
#         [0.6741, 0.8187, 0.2136, 0.0069, 0.8646, 0.7454, 0.6711, 0.7825],
#         [0.6739, 0.8196, 0.2121, 0.0090, 0.8652, 0.7435, 0.6711, 0.7825],
#         [0.0149, 0.4314, 0.5121, 0.6679, 0.3621, 0.6908, 0.0786, 0.1435],
#         [0.0146, 0.4200, 0.5100, 0.6625, 0.3531, 0.6997, 0.0671, 0.1410],
#         [0.5269, 0.7702, 0.0038, 0.2161, 0.7834, 0.5540, 0.5414, 0.6488],
#         [0.6739, 0.8202, 0.2114, 0.0099, 0.8656, 0.7426, 0.6712, 0.7826],
#         [0.1293, 0.3488, 0.6457, 0.7840, 0.2475, 0.8210, 0.1106, 0.0021]],
#        grad_fn=<CdistBackward0>)
# tensor([1, 5, 1, 3, 3, 0, 0, 2, 3, 7])
# tensor([7, 2, 0, 3, 5, 1])

# %%
indices_sample = covered_sources
plt.figure(figsize=(20,10))
with torch.no_grad():
    for i in range(6):
        plt.subplot(2,3,i+1)
        covered_source_idx = indices_sample[i]
        covering_source = torch.sum(estimated_sources[assigned_sources==covered_source_idx,:], dim=0)
        plt.plot(covering_source, 'b', label="source estimation")
        #plt.plot(torch.transpose(estimated_sources[assigned_sources==covered_source_idx,:],0,1),'g', label='estimating sources')
        plt.plot(exact_sources[covered_source_idx,:], 'r', label="original source")

        plt.title(f"Estimation of source n°{covered_source_idx}")
        plt.xlabel("time")
    plt.legend(fontsize=18)
